# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
#from api_keys import weather_api_key

api_key = 

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 588

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

api_key = "e691821b9a45feb5f99b41ad777d4ed5"

units = "imperial"

responses = []

#city_names = []

counter = 0

weather_url = f"{url}appid={api_key}&units={units}&q="

for city in cities:
    response = requests.get(weather_url + city).json()
    #city_name = response[""]
    #city_names.append(city_name)
    responses.append(response)
    #counter = counter+1
    #print(f"Processing Record {counter} of Set 1 | {city}")

# %%
pprint(responses)
# Out:
# [{'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': -42.78, 'lon': 147.06},
#   'dt': 1584227186,
#   'id': 2155415,
#   'main': {'feels_like': 52.25,
#            'humidity': 67,
#            'pressure': 1024,
#            'temp': 56.53,
#            'temp_max': 59,
#            'temp_min': 53.01},
#   'name': 'New Norfolk',
#   'sys': {'country': 'AU',
#           'id': 9545,
#           'sunrise': 1584216503,
#           'sunset': 1584261187,
#           'type': 1},
#   'timezone': 39600,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 320, 'speed': 5.82}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -24.87, 'lon': 113.63},
#   'dt': 1584227210,
#   'id': 2074865,
#   'main': {'feels_like': 80.53,
#            'humidity': 78,
#            'pressure': 1010,
#            'temp': 77,
#            'temp_max': 77,
#            'temp_min': 77},
#   'name': 'Carnarvon',
#   'sys': {'country': 'AU',
#           'id': 9505,
#           'sunrise': 1584224816,
#           'sunset': 1584268918,
#           'type': 1},
#   'timezone': 28800,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 270, 'speed': 6.93}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': -54.8, 'lon': -68.3},
#   'dt': 1584227211,
#   'id': 3833367,
#   'main': {'feels_like': 47.64,
#            'humidity': 62,
#            'pressure': 1001,
#            'temp': 53.6,
#            'temp_max': 53.6,
#            'temp_min': 53.6},
#   'name': 'Ushuaia',
#   'sys': {'country': 'AR',
#           'id': 8303,
#           'sunrise': 1584181417,
#           'sunset': 1584226860,
#           'type': 1},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 140, 'speed': 6.93}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -46.6, 'lon': 168.33},
#   'dt': 1584227211,
#   'id': 2206939,
#   'main': {'feels_like': 62.11,
#            'humidity': 75,
#            'pressure': 1011,
#            'temp': 62.01,
#            'temp_max': 62.01,
#            'temp_min': 62.01},
#   'name': 'Bluff',
#   'sys': {'country': 'NZ',
#           'id': 2008959,
#           'sunrise': 1584211308,
#           'sunset': 1584256175,
#           'type': 3},
#   'timezone': 46800,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 9, 'gust': 8.01, 'speed': 1.99}},
#  {'base': 'stations',
#   'clouds': {'all': 99},
#   'cod': 200,
#   'coord': {'lat': -13.7, 'lon': -76.22},
#   'dt': 1584227211,
#   'id': 3932145,
#   'main': {'feels_like': 58.71,
#            'humidity': 30,
#            'pressure': 1010,
#            'temp': 73.83,
#            'temp_max': 75.99,
#            'temp_min': 71.6},
#   'name': 'Pisco',
#   'sys': {'country': 'PE',
#           'id': 8691,
#           'sunrise': 1584184101,
#           'sunset': 1584227977,
#           'type': 1},
#   'timezone': -18000,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 220, 'speed': 23.04}},
#  {'base': 'stations',
#   'clouds': {'all': 59},
#   'cod': 200,
#   'coord': {'lat': 19.37, 'lon': 79.28},
#   'dt': 1584227211,
#   'id': 1278282,
#   'main': {'feels_like': 80.62,
#            'grnd_level': 985,
#            'humidity': 61,
#            'pressure': 1012,
#            'sea_level': 1012,
#            'temp': 77.14,
#            'temp_max': 77.14,
#            'temp_min': 77.14},
#   'name': 'Asifābād',
#   'sys': {'country': 'IN', 'sunrise': 1584233470, 'sunset': 1584276748},
#   'timezone': 19800,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 219, 'speed': 1.45}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': -20.41, 'lon': 57.7},
#   'dt': 1584227046,
#   'id': 934322,
#   'main': {'feels_like': 80.6,
#            'humidity': 88,
#            'pressure': 1010,
#            'temp': 76.05,
#            'temp_max': 77,
#            'temp_min': 75},
#   'name': 'Mahébourg',
#   'sys': {'country': 'MU',
#           'id': 2061,
#           'sunrise': 1584238294,
#           'sunset': 1584282280,
#           'type': 1},
#   'timezone': 14400,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 141, 'speed': 7.54}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 65.61, 'lon': -37.64},
#   'dt': 1584226984,
#   'id': 3424607,
#   'main': {'feels_like': -6.18,
#            'humidity': 65,
#            'pressure': 1005,
#            'temp': 3.2,
#            'temp_max': 3.2,
#            'temp_min': 3.2},
#   'name': 'Tasiilaq',
#   'sys': {'country': 'GL',
#           'id': 81,
#           'sunrise': 1584175921,
#           'sunset': 1584217642,
#           'type': 1},
#   'timezone': -10800,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 4, 'speed': 5.06}},
#  {'base': 'stations',
#   'clouds': {'all': 64},
#   'cod': 200,
#   'coord': {'lat': -0.6, 'lon': 73.08},
#   'dt': 1584227212,
#   'id': 1282256,
#   'main': {'feels_like': 88.2,
#            'grnd_level': 1008,
#            'humidity': 64,
#            'pressure': 1009,
#            'sea_level': 1009,
#            'temp': 82.83,
#            'temp_max': 82.83,
#            'temp_min': 82.83},
#   'name': 'Hithadhoo',
#   'sys': {'country': 'MV', 'sunrise': 1584234792, 'sunset': 1584278401},
#   'timezone': 18000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 351, 'speed': 3.47}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 43.21, 'lon': -75.46},
#   'dt': 1584226985,
#   'id': 5134295,
#   'main': {'feels_like': 25.83,
#            'humidity': 64,
#            'pressure': 1029,
#            'temp': 36.09,
#            'temp_max': 37.4,
#            'temp_min': 34},
#   'name': 'Rome',
#   'sys': {'country': 'US',
#           'id': 5681,
#           'sunrise': 1584184494,
#           'sunset': 1584227219,
#           'type': 1},
#   'timezone': -14400,
#   'visibility': 16093,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 280, 'speed': 10.29}},
#  {'base': 'stations',
#   'clouds': {'all': 51},
#   'cod': 200,
#   'coord': {'lat': 73.51, 'lon': 80.55},
#   'dt': 1584227212,
#   'id': 1507390,
#   'main': {'feels_like': -29.85,
#            'grnd_level': 989,
#            'humidity': 99,
#            'pressure': 989,
#            'sea_level': 989,
#            'temp': -18.27,
#            'temp_max': -18.27,
#            'temp_min': -18.27},
#   'name': 'Dikson',
#   'sys': {'country': 'RU', 'sunrise': 1584234159, 'sunset': 1584275449},
#   'timezone': 25200,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 352, 'speed': 8.41}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -33.01, 'lon': 17.94},
#   'dt': 1584227212,
#   'id': 3361934,
#   'main': {'feels_like': 60.15,
#            'humidity': 88,
#            'pressure': 1017,
#            'temp': 64.4,
#            'temp_max': 64.4,
#            'temp_min': 64.4},
#   'name': 'Saldanha',
#   'sys': {'country': 'ZA',
#           'id': 1943,
#           'sunrise': 1584247682,
#           'sunset': 1584291973,
#           'type': 1},
#   'timezone': 7200,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 200, 'speed': 13.87}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 42.25, 'lon': -75.83},
#   'dt': 1584227213,
#   'id': 5110365,
#   'main': {'feels_like': 27.57,
#            'humidity': 59,
#            'pressure': 1026,
#            'temp': 37.87,
#            'temp_max': 42.01,
#            'temp_min': 34},
#   'name': 'Broome',
#   'sys': {'country': 'US',
#           'id': 3429,
#           'sunrise': 1584184570,
#           'sunset': 1584227321,
#           'type': 1},
#   'timezone': -14400,
#   'visibility': 16093,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 350, 'speed': 10.29}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -25.24, 'lon': 130.99},
#   'dt': 1584227213,
#   'id': 6355222,
#   'main': {'feels_like': 65.03,
#            'humidity': 31,
#            'pressure': 1017,
#            'temp': 75.2,
#            'temp_max': 75.2,
#            'temp_min': 75.2},
#   'name': 'Yulara',
#   'sys': {'country': 'AU',
#           'id': 9487,
#           'sunrise': 1584220643,
#           'sunset': 1584264759,
#           'type': 1},
#   'timezone': 34200,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 100, 'speed': 14.99}},
#  {'base': 'stations',
#   'clouds': {'all': 98},
#   'cod': 200,
#   'coord': {'lat': 69.22, 'lon': -51.1},
#   'dt': 1584227123,
#   'id': 3423146,
#   'main': {'feels_like': -9.04,
#            'humidity': 70,
#            'pressure': 1018,
#            'temp': 1.4,
#            'temp_max': 1.4,
#            'temp_min': 1.4},
#   'name': 'Ilulissat',
#   'sys': {'country': 'GL',
#           'id': 165,
#           'sunrise': 1584179301,
#           'sunset': 1584220722,
#           'type': 1},
#   'timezone': -10800,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 250, 'speed': 6.93}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 19.73, 'lon': -155.09},
#   'dt': 1584227213,
#   'id': 5855927,
#   'main': {'feels_like': 74.12,
#            'humidity': 78,
#            'pressure': 1017,
#            'temp': 72.59,
#            'temp_max': 77,
#            'temp_min': 69.01},
#   'name': 'Hilo',
#   'sys': {'country': 'US',
#           'id': 7881,
#           'sunrise': 1584203340,
#           'sunset': 1584246588,
#           'type': 1},
#   'timezone': -36000,
#   'visibility': 16093,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 120, 'speed': 6.93}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -46.19, 'lon': 168.86},
#   'dt': 1584227214,
#   'id': 6201424,
#   'main': {'feels_like': 62.11,
#            'humidity': 75,
#            'pressure': 1011,
#            'temp': 62.01,
#            'temp_max': 62.01,
#            'temp_min': 62.01},
#   'name': 'Mataura',
#   'sys': {'country': 'NZ',
#           'id': 2008959,
#           'sunrise': 1584211190,
#           'sunset': 1584256038,
#           'type': 3},
#   'timezone': 46800,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 9, 'gust': 8.01, 'speed': 1.99}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 13.22, 'lon': -59.52},
#   'dt': 1584227214,
#   'id': 3374083,
#   'main': {'feels_like': 75.11,
#            'humidity': 88,
#            'pressure': 1013,
#            'temp': 75.2,
#            'temp_max': 75.2,
#            'temp_min': 75.2},
#   'name': 'Bathsheba',
#   'sys': {'country': 'BB',
#           'id': 8772,
#           'sunrise': 1584180356,
#           'sunset': 1584223708,
#           'type': 1},
#   'timezone': -14400,
#   'visibility': 10000,
#   'weather': [{'description': 'shower rain',
#                'icon': '09n',
#                'id': 521,
#                'main': 'Rain'}],
#   'wind': {'deg': 70, 'speed': 14.99}},
#  {'base': 'stations',
#   'clouds': {'all': 80},
#   'cod': 200,
#   'coord': {'lat': -33.65, 'lon': 115.33},
#   'dt': 1584227214,
#   'id': 2075265,
#   'main': {'feels_like': 62.69,
#            'humidity': 98,
#            'pressure': 1001,
#            'temp': 64.99,
#            'temp_max': 64.99,
#            'temp_min': 64.99},
#   'name': 'Busselton',
#   'rain': {'3h': 1.19},
#   'sys': {'country': 'AU',
#           'id': 2011706,
#           'sunrise': 1584224287,
#           'sunset': 1584268631,
#           'type': 3},
#   'timezone': 28800,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 338, 'speed': 13.04}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -35.17, 'lon': 173.17},
#   'dt': 1584227214,
#   'id': 2194098,
#   'main': {'feels_like': 63.9,
#            'grnd_level': 1014,
#            'humidity': 68,
#            'pressure': 1015,
#            'sea_level': 1015,
#            'temp': 66.87,
#            'temp_max': 66.87,
#            'temp_min': 66.87},
#   'name': 'Ahipara',
#   'sys': {'country': 'NZ', 'sunrise': 1584210373, 'sunset': 1584254787},
#   'timezone': 46800,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 208, 'speed': 8.57}},
#  {'base': 'stations',
#   'clouds': {'all': 91},
#   'cod': 200,
#   'coord': {'lat': 7.02, 'lon': 39.98},
#   'dt': 1584227214,
#   'id': 336350,
#   'main': {'feels_like': 47.84,
#            'grnd_level': 731,
#            'humidity': 80,
#            'pressure': 1012,
#            'sea_level': 1012,
#            'temp': 51.12,
#            'temp_max': 51.12,
#            'temp_min': 51.12},
#   'name': 'Goba',
#   'sys': {'country': 'ET', 'sunrise': 1584242797, 'sunset': 1584286281},
#   'timezone': 10800,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 232, 'speed': 3.83}},
#  {'base': 'stations',
#   'clouds': {'all': 98},
#   'cod': 200,
#   'coord': {'lat': 64.25, 'lon': -15.21},
#   'dt': 1584227215,
#   'id': 2630299,
#   'main': {'feels_like': 15.04,
#            'grnd_level': 1003,
#            'humidity': 68,
#            'pressure': 1003,
#            'sea_level': 1003,
#            'temp': 30.9,
#            'temp_max': 30.9,
#            'temp_min': 30.9},
#   'name': 'Hofn',
#   'sys': {'country': 'IS', 'sunrise': 1584170502, 'sunset': 1584212297},
#   'timezone': 0,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 35, 'speed': 19.55}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -24.79, 'lon': -50.01},
#   'dt': 1584227215,
#   'id': 3466704,
#   'main': {'feels_like': 64.24,
#            'grnd_level': 907,
#            'humidity': 67,
#            'pressure': 1017,
#            'sea_level': 1017,
#            'temp': 64.4,
#            'temp_max': 64.4,
#            'temp_min': 64.4},
#   'name': 'Castro',
#   'sys': {'country': 'BR', 'sunrise': 1584177676, 'sunset': 1584221824},
#   'timezone': -10800,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 66, 'speed': 2.06}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -33.93, 'lon': 18.42},
#   'dt': 1584227215,
#   'id': 3369157,
#   'main': {'feels_like': 57.83,
#            'humidity': 82,
#            'pressure': 1019,
#            'temp': 65.08,
#            'temp_max': 66,
#            'temp_min': 64},
#   'name': 'Cape Town',
#   'sys': {'country': 'ZA',
#           'id': 1899,
#           'sunrise': 1584247553,
#           'sunset': 1584291872,
#           'type': 1},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 180, 'speed': 18.34}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 59.12, 'lon': 159.97},
#   'dt': 1584227215,
#   'id': 2122262,
#   'main': {'feels_like': -0.87,
#            'grnd_level': 994,
#            'humidity': 85,
#            'pressure': 1012,
#            'sea_level': 1012,
#            'temp': 18.21,
#            'temp_max': 18.21,
#            'temp_min': 18.21},
#   'name': 'Palana',
#   'sys': {'country': 'RU', 'sunrise': 1584214614, 'sunset': 1584256881},
#   'timezone': 43200,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 195, 'speed': 24.18}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': -16.48, 'lon': -151.75},
#   'dt': 1584227215,
#   'id': 4034551,
#   'main': {'feels_like': 84.96,
#            'grnd_level': 1011,
#            'humidity': 75,
#            'pressure': 1012,
#            'sea_level': 1012,
#            'temp': 83.12,
#            'temp_max': 83.12,
#            'temp_min': 83.12},
#   'name': 'Faanui',
#   'rain': {'3h': 0.12},
#   'sys': {'country': 'PF', 'sunrise': 1584202200, 'sunset': 1584246126},
#   'timezone': -36000,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 89, 'speed': 14.47}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -23.12, 'lon': -134.97},
#   'dt': 1584227611,
#   'id': 4030556,
#   'main': {'feels_like': 79.48,
#            'grnd_level': 1013,
#            'humidity': 78,
#            'pressure': 1013,
#            'sea_level': 1013,
#            'temp': 78.26,
#            'temp_max': 78.26,
#            'temp_min': 78.26},
#   'name': 'Rikitea',
#   'rain': {'3h': 0.19},
#   'sys': {'country': 'PF', 'sunrise': 1584198094, 'sunset': 1584242179},
#   'timezone': -32400,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 101, 'speed': 12.12}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 35.73, 'lon': 140.83},
#   'dt': 1584227216,
#   'id': 2112802,
#   'main': {'feels_like': 29.07,
#            'humidity': 80,
#            'pressure': 1007,
#            'temp': 36.68,
#            'temp_max': 39.2,
#            'temp_min': 32},
#   'name': 'Hasaki',
#   'sys': {'country': 'JP',
#           'id': 7955,
#           'sunrise': 1584218859,
#           'sunset': 1584261822,
#           'type': 1},
#   'timezone': 32400,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02d',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 30, 'speed': 6.93}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -2.59, 'lon': -51.95},
#   'dt': 1584227216,
#   'id': 3387928,
#   'main': {'feels_like': 81.09,
#            'grnd_level': 1007,
#            'humidity': 95,
#            'pressure': 1011,
#            'sea_level': 1011,
#            'temp': 75.74,
#            'temp_max': 75.74,
#            'temp_min': 75.74},
#   'name': 'Senador José Porfírio',
#   'rain': {'3h': 6.94},
#   'sys': {'country': 'BR', 'sunrise': 1584178391, 'sunset': 1584222040},
#   'timezone': -10800,
#   'weather': [{'description': 'moderate rain',
#                'icon': '10n',
#                'id': 501,
#                'main': 'Rain'}],
#   'wind': {'deg': 25, 'speed': 8.08}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 60.92, 'lon': -46.05},
#   'dt': 1584227216,
#   'id': 3421719,
#   'main': {'feels_like': 14.29,
#            'humidity': 67,
#            'pressure': 1006,
#            'temp': 21.2,
#            'temp_max': 21.2,
#            'temp_min': 21.2},
#   'name': 'Narsaq',
#   'sys': {'country': 'GL',
#           'id': 47,
#           'sunrise': 1584177782,
#           'sunset': 1584219817,
#           'type': 1},
#   'timezone': -10800,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 60, 'speed': 2.24}},
#  {'base': 'stations',
#   'clouds': {'all': 10},
#   'cod': 200,
#   'coord': {'lat': 22.29, 'lon': 114.16},
#   'dt': 1584227200,
#   'id': 1819729,
#   'main': {'feels_like': 60.17,
#            'humidity': 55,
#            'pressure': 1020,
#            'temp': 66.04,
#            'temp_max': 68,
#            'temp_min': 64},
#   'name': 'Hong Kong',
#   'sys': {'country': 'HK',
#           'id': 9154,
#           'sunrise': 1584225129,
#           'sunset': 1584268350,
#           'type': 1},
#   'timezone': 28800,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 50, 'speed': 10.29}},
#  {'base': 'stations',
#   'clouds': {'all': 3},
#   'cod': 200,
#   'coord': {'lat': -20.32, 'lon': 118.57},
#   'dt': 1584227217,
#   'id': 2063042,
#   'main': {'feels_like': 80.83,
#            'humidity': 83,
#            'pressure': 1009,
#            'temp': 77,
#            'temp_max': 77,
#            'temp_min': 77},
#   'name': 'Port Hedland',
#   'sys': {'country': 'AU',
#           'id': 9585,
#           'sunrise': 1584223683,
#           'sunset': 1584267679,
#           'type': 1},
#   'timezone': 28800,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 240, 'speed': 8.05}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 42.21, 'lon': -71.69},
#   'dt': 1584227217,
#   'id': 4938048,
#   'main': {'feels_like': 34.52,
#            'humidity': 36,
#            'pressure': 1024,
#            'temp': 45.9,
#            'temp_max': 50,
#            'temp_min': 41},
#   'name': 'Grafton',
#   'sys': {'country': 'US',
#           'id': 3413,
#           'sunrise': 1584183577,
#           'sunset': 1584226327,
#           'type': 1},
#   'timezone': -14400,
#   'visibility': 16093,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 280, 'gust': 23.04, 'speed': 11.41}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 5.41, 'lon': 100.34},
#   'dt': 1584227218,
#   'id': 1735106,
#   'main': {'feels_like': 90.37,
#            'humidity': 83,
#            'pressure': 1009,
#            'temp': 81.45,
#            'temp_max': 82.4,
#            'temp_min': 80.01},
#   'name': 'George Town',
#   'sys': {'country': 'MY',
#           'id': 9438,
#           'sunrise': 1584228302,
#           'sunset': 1584271809,
#           'type': 1},
#   'timezone': 28800,
#   'visibility': 9000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 30, 'speed': 3.36}},
#  {'base': 'stations',
#   'clouds': {'all': 63},
#   'cod': 200,
#   'coord': {'lat': -34.42, 'lon': 19.23},
#   'dt': 1584227218,
#   'id': 3366880,
#   'main': {'feels_like': 67.12,
#            'humidity': 96,
#            'pressure': 1015,
#            'temp': 63.9,
#            'temp_max': 64.99,
#            'temp_min': 63},
#   'name': 'Hermanus',
#   'rain': {'3h': 0.31},
#   'sys': {'country': 'ZA',
#           'id': 2006131,
#           'sunrise': 1584247351,
#           'sunset': 1584291685,
#           'type': 3},
#   'timezone': 7200,
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 331, 'gust': 5.99, 'speed': 1.99}},
#  {'base': 'stations',
#   'clouds': {'all': 83},
#   'cod': 200,
#   'coord': {'lat': -34.53, 'lon': 20.04},
#   'dt': 1584227005,
#   'id': 1015776,
#   'main': {'feels_like': 65.73,
#            'humidity': 82,
#            'pressure': 1018,
#            'temp': 64.69,
#            'temp_max': 66.2,
#            'temp_min': 63},
#   'name': 'Bredasdorp',
#   'rain': {'3h': 0.38},
#   'sys': {'country': 'ZA',
#           'id': 1966,
#           'sunrise': 1584247155,
#           'sunset': 1584291492,
#           'type': 1},
#   'timezone': 7200,
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 300, 'speed': 3.36}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 65.28, 'lon': -126.83},
#   'dt': 1584227218,
#   'id': 6089245,
#   'main': {'feels_like': 10.83,
#            'humidity': 85,
#            'pressure': 1028,
#            'temp': 17.6,
#            'temp_max': 17.6,
#            'temp_min': 17.6},
#   'name': 'Norman Wells',
#   'sys': {'country': 'CA',
#           'id': 951,
#           'sunrise': 1584197259,
#           'sunset': 1584239107,
#           'type': 1},
#   'timezone': -21600,
#   'visibility': 1609,
#   'weather': [{'description': 'light snow',
#                'icon': '13d',
#                'id': 600,
#                'main': 'Snow'}],
#   'wind': {'deg': 270, 'speed': 2.24}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -6.72, 'lon': 146.98},
#   'dt': 1584227219,
#   'id': 2092740,
#   'main': {'feels_like': 79.47,
#            'grnd_level': 891,
#            'humidity': 65,
#            'pressure': 1010,
#            'sea_level': 1010,
#            'temp': 77.27,
#            'temp_max': 77.27,
#            'temp_min': 77.27},
#   'name': 'Lae',
#   'sys': {'country': 'PG', 'sunrise': 1584217004, 'sunset': 1584260725},
#   'timezone': 36000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 221, 'speed': 5.17}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': -42.88, 'lon': 147.33},
#   'dt': 1584227084,
#   'id': 2163355,
#   'main': {'feels_like': 52.61,
#            'humidity': 67,
#            'pressure': 1024,
#            'temp': 56.82,
#            'temp_max': 59,
#            'temp_min': 53.01},
#   'name': 'Hobart',
#   'sys': {'country': 'AU',
#           'id': 9545,
#           'sunrise': 1584216436,
#           'sunset': 1584261125,
#           'type': 1},
#   'timezone': 39600,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 320, 'speed': 5.82}},
#  {'base': 'stations',
#   'clouds': {'all': 96},
#   'cod': 200,
#   'coord': {'lat': -24.7, 'lon': 44.75},
#   'dt': 1584227219,
#   'id': 1078553,
#   'main': {'feels_like': 77.31,
#            'grnd_level': 975,
#            'humidity': 71,
#            'pressure': 1010,
#            'sea_level': 1010,
#            'temp': 74.3,
#            'temp_max': 74.3,
#            'temp_min': 74.3},
#   'name': 'Ampanihy',
#   'sys': {'country': 'MG', 'sunrise': 1584241354, 'sunset': 1584285435},
#   'timezone': 10800,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 104, 'speed': 3.51}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -53.15, 'lon': -70.92},
#   'dt': 1584227219,
#   'id': 3874787,
#   'main': {'feels_like': 45.84,
#            'humidity': 67,
#            'pressure': 1006,
#            'temp': 56.03,
#            'temp_max': 57.2,
#            'temp_min': 55},
#   'name': 'Punta Arenas',
#   'sys': {'country': 'CL',
#           'id': 8487,
#           'sunrise': 1584182106,
#           'sunset': 1584227429,
#           'type': 1},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 310, 'speed': 16.11}},
#  {'base': 'stations',
#   'clouds': {'all': 67},
#   'cod': 200,
#   'coord': {'lat': -0.95, 'lon': 100.35},
#   'dt': 1584227219,
#   'id': 1633419,
#   'main': {'feels_like': 72.93,
#            'grnd_level': 935,
#            'humidity': 92,
#            'pressure': 1010,
#            'sea_level': 1010,
#            'temp': 69.39,
#            'temp_max': 69.39,
#            'temp_min': 69.39},
#   'name': 'Padang',
#   'sys': {'country': 'ID', 'sunrise': 1584228246, 'sunset': 1584271861},
#   'timezone': 25200,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 65, 'speed': 4.65}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 42.1, 'lon': -79.24},
#   'dt': 1584227360,
#   'id': 5122534,
#   'main': {'feels_like': 24.57,
#            'humidity': 80,
#            'pressure': 1029,
#            'temp': 32.68,
#            'temp_max': 37.99,
#            'temp_min': 30},
#   'name': 'Jamestown',
#   'sys': {'country': 'US',
#           'id': 4588,
#           'sunrise': 1584185386,
#           'sunset': 1584228142,
#           'type': 1},
#   'timezone': -14400,
#   'visibility': 16093,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 340, 'speed': 6.93}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 51.71, 'lon': 143.23},
#   'dt': 1584227220,
#   'id': 2122783,
#   'main': {'feels_like': 8.2,
#            'grnd_level': 1004,
#            'humidity': 92,
#            'pressure': 1012,
#            'sea_level': 1012,
#            'temp': 17.06,
#            'temp_max': 17.06,
#            'temp_min': 17.06},
#   'name': 'Katangli',
#   'snow': {'3h': 0.44},
#   'sys': {'country': 'RU', 'sunrise': 1584218485, 'sunset': 1584261044},
#   'timezone': 39600,
#   'weather': [{'description': 'light snow',
#                'icon': '13d',
#                'id': 600,
#                'main': 'Snow'}],
#   'wind': {'deg': 35, 'speed': 6.11}},
#  {'base': 'stations',
#   'clouds': {'all': 95},
#   'cod': 200,
#   'coord': {'lat': -33.92, 'lon': 25.57},
#   'dt': 1584227120,
#   'id': 964420,
#   'main': {'feels_like': 63.25,
#            'humidity': 82,
#            'pressure': 1016,
#            'temp': 66.2,
#            'temp_max': 66.2,
#            'temp_min': 66.2},
#   'name': 'Port Elizabeth',
#   'sys': {'country': 'ZA',
#           'id': 1973,
#           'sunrise': 1584245836,
#           'sunset': 1584290157,
#           'type': 1},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 260, 'speed': 11.41}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 25.67, 'lon': -80.44},
#   'dt': 1584227220,
#   'id': 4175117,
#   'main': {'feels_like': 77.47,
#            'humidity': 65,
#            'pressure': 1022,
#            'temp': 78.35,
#            'temp_max': 80.6,
#            'temp_min': 75.99},
#   'name': 'The Hammocks',
#   'sys': {'country': 'US',
#           'id': 4896,
#           'sunrise': 1584185491,
#           'sunset': 1584228612,
#           'type': 1},
#   'timezone': -14400,
#   'visibility': 16093,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 100, 'speed': 11.41}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 62.58, 'lon': 6.13},
#   'dt': 1584227220,
#   'id': 3141667,
#   'main': {'feels_like': 27.59,
#            'humidity': 56,
#            'pressure': 998,
#            'temp': 40.41,
#            'temp_max': 42.8,
#            'temp_min': 39},
#   'name': 'Roald',
#   'sys': {'country': 'NO',
#           'id': 1602,
#           'sunrise': 1584251536,
#           'sunset': 1584293787,
#           'type': 1},
#   'timezone': 3600,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 180, 'speed': 14.99}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 71.04, 'lon': 27.85},
#   'dt': 1584227221,
#   'id': 778707,
#   'main': {'feels_like': 0.45,
#            'grnd_level': 974,
#            'humidity': 92,
#            'pressure': 992,
#            'sea_level': 992,
#            'temp': 15.26,
#            'temp_max': 15.26,
#            'temp_min': 15.26},
#   'name': 'Mehamn',
#   'snow': {'3h': 0.5},
#   'sys': {'country': 'NO', 'sunrise': 1584246623, 'sunset': 1584288276},
#   'timezone': 3600,
#   'weather': [{'description': 'light snow',
#                'icon': '13n',
#                'id': 600,
#                'main': 'Snow'}],
#   'wind': {'deg': 163, 'speed': 16.44}},
#  {'base': 'stations',
#   'clouds': {'all': 97},
#   'cod': 200,
#   'coord': {'lat': -10.34, 'lon': -67.19},
#   'dt': 1584227221,
#   'id': 3924895,
#   'main': {'feels_like': 87.75,
#            'grnd_level': 987,
#            'humidity': 86,
#            'pressure': 1007,
#            'sea_level': 1007,
#            'temp': 78.91,
#            'temp_max': 78.91,
#            'temp_min': 78.91},
#   'name': 'Plácido de Castro',
#   'rain': {'3h': 0.31},
#   'sys': {'country': 'BR', 'sunrise': 1584181970, 'sunset': 1584225775},
#   'timezone': -14400,
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 53, 'speed': 2.01}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -7.51, 'lon': -63.02},
#   'dt': 1584227221,
#   'id': 3664078,
#   'main': {'feels_like': 84.74,
#            'grnd_level': 1003,
#            'humidity': 98,
#            'pressure': 1009,
#            'sea_level': 1009,
#            'temp': 75.52,
#            'temp_max': 75.52,
#            'temp_min': 75.52},
#   'name': 'Humaitá',
#   'rain': {'3h': 1.31},
#   'sys': {'country': 'BR', 'sunrise': 1584180998, 'sunset': 1584224745},
#   'timezone': -14400,
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 358, 'speed': 1.92}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': -33.02, 'lon': 27.91},
#   'dt': 1584227221,
#   'id': 1006984,
#   'main': {'feels_like': 72.64,
#            'grnd_level': 1011,
#            'humidity': 78,
#            'pressure': 1015,
#            'sea_level': 1015,
#            'temp': 72.68,
#            'temp_max': 72.68,
#            'temp_min': 72.68},
#   'name': 'East London',
#   'sys': {'country': 'ZA', 'sunrise': 1584245288, 'sunset': 1584289583},
#   'timezone': 7200,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 256, 'speed': 9.78}},
#  {'base': 'stations',
#   'clouds': {'all': 9},
#   'cod': 200,
#   'coord': {'lat': -14.25, 'lon': 129.55},
#   'dt': 1584227222,
#   'id': 2063039,
#   'main': {'feels_like': 91.87,
#            'grnd_level': 1008,
#            'humidity': 55,
#            'pressure': 1009,
#            'sea_level': 1009,
#            'temp': 88.16,
#            'temp_max': 88.16,
#            'temp_min': 88.16},
#   'name': 'Port Keats',
#   'sys': {'country': 'AU', 'sunrise': 1584221113, 'sunset': 1584264980},
#   'timezone': 34200,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 145, 'speed': 6.89}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 36.62, 'lon': -121.92},
#   'dt': 1584227222,
#   'id': 5380437,
#   'main': {'feels_like': 40.44,
#            'humidity': 58,
#            'pressure': 1016,
#            'temp': 53.22,
#            'temp_max': 60.01,
#            'temp_min': 46},
#   'name': 'Pacific Grove',
#   'sys': {'country': 'US',
#           'id': 4980,
#           'sunrise': 1584195552,
#           'sunset': 1584238458,
#           'type': 1},
#   'timezone': -25200,
#   'visibility': 16093,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 220, 'gust': 26.4, 'speed': 18.34}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 77.48, 'lon': -69.36},
#   'dt': 1584227222,
#   'id': 3831208,
#   'main': {'feels_like': -31.07,
#            'grnd_level': 979,
#            'humidity': 58,
#            'pressure': 1021,
#            'sea_level': 1021,
#            'temp': -20.81,
#            'temp_max': -20.81,
#            'temp_min': -20.81},
#   'name': 'Qaanaaq',
#   'sys': {'country': 'GL', 'sunrise': 1584184334, 'sunset': 1584224452},
#   'timezone': -10800,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 60, 'speed': 5.75}},
#  {'base': 'stations',
#   'clouds': {'all': 14},
#   'cod': 200,
#   'coord': {'lat': 71.69, 'lon': 128.87},
#   'dt': 1584227222,
#   'id': 2015306,
#   'main': {'feels_like': -25.17,
#            'grnd_level': 987,
#            'humidity': 71,
#            'pressure': 1003,
#            'sea_level': 1003,
#            'temp': -14.58,
#            'temp_max': -14.58,
#            'temp_min': -14.58},
#   'name': 'Tiksi',
#   'sys': {'country': 'RU', 'sunrise': 1584222496, 'sunset': 1584263924},
#   'timezone': 32400,
#   'weather': [{'description': 'few clouds',
#                'icon': '02d',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 160, 'speed': 6.55}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 17.65, 'lon': 83.27},
#   'dt': 1584227223,
#   'id': 1252783,
#   'main': {'feels_like': 84.92,
#            'grnd_level': 1011,
#            'humidity': 68,
#            'pressure': 1011,
#            'sea_level': 1011,
#            'temp': 79.39,
#            'temp_max': 79.39,
#            'temp_min': 79.39},
#   'name': 'Yārāda',
#   'sys': {'country': 'IN', 'sunrise': 1584232499, 'sunset': 1584275805},
#   'timezone': 19800,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 48, 'speed': 1.92}},
#  {'base': 'stations',
#   'clouds': {'all': 27},
#   'cod': 200,
#   'coord': {'lat': 26.33, 'lon': 43.98},
#   'dt': 1584227223,
#   'id': 107304,
#   'main': {'feels_like': 59.09,
#            'humidity': 68,
#            'pressure': 1013,
#            'temp': 64.4,
#            'temp_max': 64.4,
#            'temp_min': 64.4},
#   'name': 'Buraidah',
#   'sys': {'country': 'SA',
#           'id': 7411,
#           'sunrise': 1584241995,
#           'sunset': 1584285164,
#           'type': 1},
#   'timezone': 10800,
#   'visibility': 9000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 350, 'speed': 11.41}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 41},
#   'cod': 200,
#   'coord': {'lat': -3.39, 'lon': 38.56},
#   'dt': 1584227223,
#   'id': 178522,
#   'main': {'feels_like': 77.94,
#            'grnd_level': 922,
#            'humidity': 93,
#            'pressure': 1010,
#            'sea_level': 1010,
#            'temp': 71.42,
#            'temp_max': 71.42,
#            'temp_min': 71.42},
#   'name': 'Voi',
#   'rain': {'3h': 0.37},
#   'sys': {'country': 'KE', 'sunrise': 1584243052, 'sunset': 1584286708},
#   'timezone': 10800,
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 197, 'speed': 1.34}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': -20.01, 'lon': 57.66},
#   'dt': 1584227224,
#   'id': 934479,
#   'main': {'feels_like': 78.84,
#            'humidity': 88,
#            'pressure': 1010,
#            'temp': 75.81,
#            'temp_max': 77,
#            'temp_min': 75},
#   'name': 'Grand Gaube',
#   'sys': {'country': 'MU',
#           'id': 2061,
#           'sunrise': 1584238308,
#           'sunset': 1584282285,
#           'type': 1},
#   'timezone': 14400,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 144, 'speed': 10.02}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 42.6, 'lon': -73.97},
#   'dt': 1584227112,
#   'id': 5106841,
#   'main': {'feels_like': 23.59,
#            'humidity': 48,
#            'pressure': 1028,
#            'temp': 37.69,
#            'temp_max': 42.01,
#            'temp_min': 33.01},
#   'name': 'Albany',
#   'sys': {'country': 'US',
#           'id': 3273,
#           'sunrise': 1584184129,
#           'sunset': 1584226869,
#           'type': 1},
#   'timezone': -14400,
#   'visibility': 16093,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 290, 'speed': 16.11}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -26.65, 'lon': 15.16},
#   'dt': 1584227225,
#   'id': 3355672,
#   'main': {'feels_like': 66.87,
#            'humidity': 64,
#            'pressure': 1013,
#            'temp': 69.8,
#            'temp_max': 69.8,
#            'temp_min': 69.8},
#   'name': 'Lüderitz',
#   'sys': {'country': 'NA',
#           'id': 2260,
#           'sunrise': 1584248434,
#           'sunset': 1584292555,
#           'type': 1},
#   'timezone': 7200,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 170, 'speed': 9.17}},
#  {'base': 'stations',
#   'clouds': {'all': 96},
#   'cod': 200,
#   'coord': {'lat': -8.14, 'lon': 159.59},
#   'dt': 1584227226,
#   'id': 2109528,
#   'main': {'feels_like': 88.97,
#            'grnd_level': 1000,
#            'humidity': 76,
#            'pressure': 1009,
#            'sea_level': 1009,
#            'temp': 84.29,
#            'temp_max': 84.29,
#            'temp_min': 84.29},
#   'name': 'Buala',
#   'rain': {'3h': 0.56},
#   'sys': {'country': 'SB', 'sunrise': 1584213964, 'sunset': 1584257713},
#   'timezone': 39600,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 322, 'speed': 10.98}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 35.13, 'lon': 140.3},
#   'dt': 1584227226,
#   'id': 2112309,
#   'main': {'feels_like': 33.1,
#            'humidity': 60,
#            'pressure': 1007,
#            'temp': 42.76,
#            'temp_max': 43,
#            'temp_min': 42.01},
#   'name': 'Katsuura',
#   'sys': {'country': 'JP',
#           'id': 8074,
#           'sunrise': 1584218980,
#           'sunset': 1584261955,
#           'type': 1},
#   'timezone': 32400,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02d',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 340, 'speed': 10.29}},
#  {'cod': '404', 'message': 'city not found'},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 23},
#   'cod': 200,
#   'coord': {'lat': 54.42, 'lon': 16.41},
#   'dt': 1584227226,
#   'id': 3100637,
#   'main': {'feels_like': 19.4,
#            'humidity': 51,
#            'pressure': 1026,
#            'temp': 32,
#            'temp_max': 32,
#            'temp_min': 32},
#   'name': 'Darłowo',
#   'sys': {'country': 'PL',
#           'id': 2017076,
#           'sunrise': 1584248914,
#           'sunset': 1584291476,
#           'type': 3},
#   'timezone': 3600,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 171, 'speed': 12.86}},
#  {'base': 'stations',
#   'clouds': {'all': 43},
#   'cod': 200,
#   'coord': {'lat': -21.34, 'lon': 55.48},
#   'dt': 1584227227,
#   'id': 935214,
#   'main': {'feels_like': 74.93,
#            'humidity': 83,
#            'pressure': 1010,
#            'temp': 73.02,
#            'temp_max': 77,
#            'temp_min': 66},
#   'name': 'Saint-Pierre',
#   'sys': {'country': 'RE',
#           'id': 2127,
#           'sunrise': 1584238817,
#           'sunset': 1584282823,
#           'type': 1},
#   'timezone': 14400,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 90, 'speed': 8.05}},
#  {'base': 'stations',
#   'clouds': {'all': 77},
#   'cod': 200,
#   'coord': {'lat': 9.27, 'lon': -3},
#   'dt': 1584227227,
#   'id': 2290849,
#   'main': {'feels_like': 85.06,
#            'grnd_level': 974,
#            'humidity': 54,
#            'pressure': 1009,
#            'sea_level': 1009,
#            'temp': 83.75,
#            'temp_max': 83.75,
#            'temp_min': 83.75},
#   'name': 'Bouna',
#   'sys': {'country': 'CI', 'sunrise': 1584166760, 'sunset': 1584210180},
#   'timezone': 0,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 173, 'speed': 7.29}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 70.47, 'lon': -68.59},
#   'dt': 1584226985,
#   'id': 5924351,
#   'main': {'feels_like': -34.51,
#            'humidity': 74,
#            'pressure': 1023,
#            'temp': -25.6,
#            'temp_max': -25.6,
#            'temp_min': -25.6},
#   'name': 'Clyde River',
#   'sys': {'country': 'CA',
#           'id': 776,
#           'sunrise': 1584183552,
#           'sunset': 1584224865,
#           'type': 1},
#   'timezone': -14400,
#   'visibility': 40233,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 250, 'speed': 3.36}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -3.38, 'lon': -57.72},
#   'dt': 1584227227,
#   'id': 3395062,
#   'main': {'feels_like': 84.67,
#            'grnd_level': 1006,
#            'humidity': 98,
#            'pressure': 1011,
#            'sea_level': 1011,
#            'temp': 75.06,
#            'temp_max': 75.06,
#            'temp_min': 75.06},
#   'name': 'Maués',
#   'rain': {'3h': 5.19},
#   'sys': {'country': 'BR', 'sunrise': 1584179768, 'sunset': 1584223432},
#   'timezone': -14400,
#   'weather': [{'description': 'moderate rain',
#                'icon': '10n',
#                'id': 501,
#                'main': 'Rain'}],
#   'wind': {'deg': 199, 'speed': 0.76}},
#  {'base': 'stations',
#   'clouds': {'all': 96},
#   'cod': 200,
#   'coord': {'lat': 59.48, 'lon': 11.66},
#   'dt': 1584227228,
#   'id': 3143427,
#   'main': {'feels_like': 21.4,
#            'humidity': 69,
#            'pressure': 1014,
#            'temp': 37.24,
#            'temp_max': 39.2,
#            'temp_min': 36},
#   'name': 'Ørje',
#   'sys': {'country': 'NO',
#           'id': 1662,
#           'sunrise': 1584250143,
#           'sunset': 1584292526,
#           'type': 1},
#   'timezone': 3600,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 180, 'speed': 20.8}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -14.9, 'lon': 50.28},
#   'dt': 1584226953,
#   'id': 1071296,
#   'main': {'feels_like': 62.2,
#            'grnd_level': 996,
#            'humidity': 92,
#            'pressure': 1000,
#            'sea_level': 1000,
#            'temp': 78.91,
#            'temp_max': 78.91,
#            'temp_min': 78.91},
#   'name': 'Antalaha',
#   'rain': {'3h': 70.31},
#   'sys': {'country': 'MG', 'sunrise': 1584240133, 'sunset': 1584284002},
#   'timezone': 10800,
#   'weather': [{'description': 'very heavy rain',
#                'icon': '10n',
#                'id': 503,
#                'main': 'Rain'}],
# ...
#            'temp_min': 67.82},
#   'name': 'Rāpar',
#   'sys': {'country': 'IN', 'sunrise': 1584235580, 'sunset': 1584278789},
#   'timezone': 19800,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 43, 'speed': 6.89}},
#  {'base': 'stations',
#   'clouds': {'all': 84},
#   'cod': 200,
#   'coord': {'lat': 36.21, 'lon': 58.8},
#   'dt': 1584227344,
#   'id': 122285,
#   'main': {'feels_like': 48.29,
#            'grnd_level': 870,
#            'humidity': 25,
#            'pressure': 1009,
#            'sea_level': 1009,
#            'temp': 58.1,
#            'temp_max': 58.1,
#            'temp_min': 58.1},
#   'name': 'Neyshabur',
#   'sys': {'country': 'IR', 'sunrise': 1584238531, 'sunset': 1584281516},
#   'timezone': 12600,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 114, 'speed': 8.99}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 46.43, 'lon': 141.86},
#   'dt': 1584227344,
#   'id': 2121324,
#   'main': {'feels_like': 21.27,
#            'grnd_level': 985,
#            'humidity': 78,
#            'pressure': 1008,
#            'sea_level': 1008,
#            'temp': 27.59,
#            'temp_max': 27.59,
#            'temp_min': 27.59},
#   'name': 'Shebunino',
#   'sys': {'country': 'RU', 'sunrise': 1584218736, 'sunset': 1584261450},
#   'timezone': 39600,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 12, 'speed': 2.64}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 69.3, 'lon': 139.9},
#   'dt': 1584227345,
#   'id': 2028164,
#   'main': {'feels_like': -36.29,
#            'grnd_level': 952,
#            'humidity': 91,
#            'pressure': 1012,
#            'sea_level': 1012,
#            'temp': -28.21,
#            'temp_max': -28.21,
#            'temp_min': -28.21},
#   'name': 'Deputatsky',
#   'sys': {'country': 'RU', 'sunrise': 1584219739, 'sunset': 1584261388},
#   'timezone': 36000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 99, 'speed': 1.9}},
#  {'base': 'stations',
#   'clouds': {'all': 68},
#   'cod': 200,
#   'coord': {'lat': -20.02, 'lon': 148.23},
#   'dt': 1584227345,
#   'id': 2174444,
#   'main': {'feels_like': 82.9,
#            'humidity': 78,
#            'pressure': 1009,
#            'temp': 77.76,
#            'temp_max': 81,
#            'temp_min': 73.4},
#   'name': 'Bowen',
#   'sys': {'country': 'AU',
#           'id': 9503,
#           'sunrise': 1584216567,
#           'sunset': 1584260562,
#           'type': 1},
#   'timezone': 36000,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 200, 'speed': 4.7}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -45.87, 'lon': 170.5},
#   'dt': 1584227345,
#   'id': 2191562,
#   'main': {'feels_like': 58.33,
#            'humidity': 69,
#            'pressure': 995,
#            'temp': 59.54,
#            'temp_max': 61,
#            'temp_min': 57.99},
#   'name': 'Dunedin',
#   'sys': {'country': 'NZ',
#           'id': 2031989,
#           'sunrise': 1584210804,
#           'sunset': 1584255638,
#           'type': 3},
#   'timezone': 46800,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 90, 'gust': 8.99, 'speed': 1.99}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': -23.32, 'lon': -46.22},
#   'dt': 1584227345,
#   'id': 3450188,
#   'main': {'feels_like': 69.78,
#            'humidity': 73,
#            'pressure': 1018,
#            'temp': 72.86,
#            'temp_max': 73.4,
#            'temp_min': 71.6},
#   'name': 'Santa Isabel',
#   'sys': {'country': 'BR',
#           'id': 8434,
#           'sunrise': 1584176785,
#           'sunset': 1584220896,
#           'type': 1},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 130, 'speed': 13.87}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 69.01, 'lon': 23.04},
#   'dt': 1584227346,
#   'id': 779330,
#   'main': {'feels_like': -5.57,
#            'grnd_level': 938,
#            'humidity': 79,
#            'pressure': 989,
#            'sea_level': 989,
#            'temp': 21.31,
#            'temp_max': 21.31,
#            'temp_min': 21.31},
#   'name': 'Kautokeino',
#   'snow': {'3h': 0.56},
#   'sys': {'country': 'NO', 'sunrise': 1584247686, 'sunset': 1584289522},
#   'timezone': 3600,
#   'weather': [{'description': 'light snow',
#                'icon': '13n',
#                'id': 600,
#                'main': 'Snow'}],
#   'wind': {'deg': 205, 'speed': 38.18}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -14.92, 'lon': 13.49},
#   'dt': 1584227346,
#   'id': 3347762,
#   'main': {'feels_like': 62.89,
#            'grnd_level': 815,
#            'humidity': 89,
#            'pressure': 1012,
#            'sea_level': 1012,
#            'temp': 61.75,
#            'temp_max': 61.75,
#            'temp_min': 61.75},
#   'name': 'Lubango',
#   'rain': {'3h': 1.56},
#   'sys': {'country': 'AO', 'sunrise': 1584248963, 'sunset': 1584292828},
#   'timezone': 3600,
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 174, 'speed': 2.82}},
#  {'base': 'stations',
#   'clouds': {'all': 87},
#   'cod': 200,
#   'coord': {'lat': 8.47, 'lon': -0.01},
#   'dt': 1584227346,
#   'id': 2299236,
#   'main': {'feels_like': 86.88,
#            'grnd_level': 991,
#            'humidity': 63,
#            'pressure': 1009,
#            'sea_level': 1009,
#            'temp': 83.34,
#            'temp_max': 83.34,
#            'temp_min': 83.34},
#   'name': 'Kpandae',
#   'sys': {'country': 'GH', 'sunrise': 1584166035, 'sunset': 1584209470},
#   'timezone': 0,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 179, 'speed': 6.71}},
#  {'base': 'stations',
#   'clouds': {'all': 91},
#   'cod': 200,
#   'coord': {'lat': -31.59, 'lon': 28.78},
#   'dt': 1584227346,
#   'id': 946058,
#   'main': {'feels_like': 68.58,
#            'humidity': 88,
#            'pressure': 1018,
#            'temp': 66.2,
#            'temp_max': 66.2,
#            'temp_min': 66.2},
#   'name': 'Mthatha',
#   'sys': {'country': 'ZA',
#           'id': 1996,
#           'sunrise': 1584245099,
#           'sunset': 1584289354,
#           'type': 1},
#   'timezone': 7200,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 140, 'speed': 3.36}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 67.67, 'lon': 12.69},
#   'dt': 1584227347,
#   'id': 3137469,
#   'main': {'feels_like': 15.44,
#            'grnd_level': 988,
#            'humidity': 66,
#            'pressure': 989,
#            'sea_level': 989,
#            'temp': 40.32,
#            'temp_max': 40.32,
#            'temp_min': 40.32},
#   'name': 'Sørland',
#   'snow': {'3h': 1.75},
#   'sys': {'country': 'NO', 'sunrise': 1584250113, 'sunset': 1584292062},
#   'timezone': 3600,
#   'weather': [{'description': 'snow',
#                'icon': '13n',
#                'id': 601,
#                'main': 'Snow'}],
#   'wind': {'deg': 256, 'speed': 37.29}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': -22.47, 'lon': -68.93},
#   'dt': 1584227347,
#   'id': 3897347,
#   'main': {'feels_like': 57.94,
#            'humidity': 16,
#            'pressure': 1025,
#            'temp': 77,
#            'temp_max': 77,
#            'temp_min': 77},
#   'name': 'Calama',
#   'sys': {'country': 'CL',
#           'id': 8480,
#           'sunrise': 1584182248,
#           'sunset': 1584226331,
#           'type': 1},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 260, 'speed': 26.4}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 42, 'lon': 8.92},
#   'dt': 1584227347,
#   'id': 3038333,
#   'main': {'feels_like': 50.74,
#            'humidity': 87,
#            'pressure': 1018,
#            'temp': 52.81,
#            'temp_max': 55.4,
#            'temp_min': 48.2},
#   'name': "Arrondissement d'Ajaccio",
#   'sys': {'country': 'FR',
#           'id': 6492,
#           'sunrise': 1584250548,
#           'sunset': 1584293436,
#           'type': 1},
#   'timezone': 3600,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 50, 'speed': 3.36}},
#  {'base': 'stations',
#   'clouds': {'all': 84},
#   'cod': 200,
#   'coord': {'lat': -8.12, 'lon': 111.89},
#   'dt': 1584227347,
#   'id': 1648082,
#   'main': {'feels_like': 86.32,
#            'grnd_level': 991,
#            'humidity': 87,
#            'pressure': 1010,
#            'sea_level': 1010,
#            'temp': 77.2,
#            'temp_max': 77.2,
#            'temp_min': 77.2},
#   'name': 'Boyolangu',
#   'sys': {'country': 'ID', 'sunrise': 1584225412, 'sunset': 1584269157},
#   'timezone': 25200,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 275, 'speed': 0.18}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 18.2, 'lon': -73.75},
#   'dt': 1584227348,
#   'id': 3728097,
#   'main': {'feels_like': 83.16,
#            'grnd_level': 1016,
#            'humidity': 74,
#            'pressure': 1016,
#            'sea_level': 1016,
#            'temp': 79.92,
#            'temp_max': 79.92,
#            'temp_min': 79.92},
#   'name': 'Les Cayes',
#   'sys': {'country': 'HT', 'sunrise': 1584183816, 'sunset': 1584227077},
#   'timezone': -14400,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 273, 'speed': 8.59}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 54.52, 'lon': 9.55},
#   'dt': 1584227311,
#   'id': 2838634,
#   'main': {'feels_like': 28.35,
#            'humidity': 69,
#            'pressure': 1018,
#            'temp': 39.38,
#            'temp_max': 41,
#            'temp_min': 37.99},
#   'name': 'Schleswig',
#   'sys': {'country': 'DE',
#           'id': 1851,
#           'sunrise': 1584250559,
#           'sunset': 1584293123,
#           'type': 1},
#   'timezone': 3600,
#   'visibility': 9000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 160, 'speed': 12.75}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -45.42, 'lon': 167.72},
#   'dt': 1584227348,
#   'id': 2181625,
#   'main': {'feels_like': 57.65,
#            'grnd_level': 957,
#            'humidity': 59,
#            'pressure': 1010,
#            'sea_level': 1010,
#            'temp': 59.43,
#            'temp_max': 59.43,
#            'temp_min': 59.43},
#   'name': 'Te Anau',
#   'sys': {'country': 'NZ', 'sunrise': 1584211482, 'sunset': 1584256293},
#   'timezone': 46800,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 333, 'speed': 1.12}},
#  {'base': 'stations',
#   'clouds': {'all': 93},
#   'cod': 200,
#   'coord': {'lat': 29.03, 'lon': 21.55},
#   'dt': 1584227348,
#   'id': 86049,
#   'main': {'feels_like': 57.81,
#            'grnd_level': 1010,
#            'humidity': 36,
#            'pressure': 1017,
#            'sea_level': 1017,
#            'temp': 63.05,
#            'temp_max': 63.05,
#            'temp_min': 63.05},
#   'name': 'Jalu',
#   'sys': {'country': 'LY', 'sunrise': 1584247397, 'sunset': 1584290526},
#   'timezone': 7200,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 236, 'speed': 3.96}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': -18.85, 'lon': -41.95},
#   'dt': 1584227096,
#   'id': 3462315,
#   'main': {'feels_like': 76.39,
#            'grnd_level': 987,
#            'humidity': 95,
#            'pressure': 1017,
#            'sea_level': 1017,
#            'temp': 71.4,
#            'temp_max': 71.4,
#            'temp_min': 71.4},
#   'name': 'Governador Valadares',
#   'rain': {'3h': 0.31},
#   'sys': {'country': 'BR', 'sunrise': 1584175816, 'sunset': 1584219816},
#   'timezone': -10800,
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 65, 'speed': 4.61}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 14.51, 'lon': -92.19},
#   'dt': 1584227349,
#   'id': 3592086,
#   'main': {'feels_like': 93.6,
#            'humidity': 70,
#            'pressure': 1014,
#            'temp': 86.72,
#            'temp_max': 89.6,
#            'temp_min': 84.2},
#   'name': 'Ocós',
#   'sys': {'country': 'GT',
#           'id': 7068,
#           'sunrise': 1584188205,
#           'sunset': 1584231537,
#           'type': 1},
#   'timezone': -21600,
#   'visibility': 8000,
#   'weather': [{'description': 'haze',
#                'icon': '50d',
#                'id': 721,
#                'main': 'Haze'}],
#   'wind': {'deg': 220, 'speed': 6.93}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -9.44, 'lon': 147.18},
#   'dt': 1584227349,
#   'id': 2088122,
#   'main': {'feels_like': 81.01,
#            'humidity': 94,
#            'pressure': 1010,
#            'temp': 77,
#            'temp_max': 77,
#            'temp_min': 77},
#   'name': 'Port Moresby',
#   'sys': {'country': 'PG',
#           'id': 42,
#           'sunrise': 1584216930,
#           'sunset': 1584260703,
#           'type': 1},
#   'timezone': 36000,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 350, 'speed': 11.41}},
#  {'base': 'stations',
#   'clouds': {'all': 5},
#   'cod': 200,
#   'coord': {'lat': -40.85, 'lon': 172.8},
#   'dt': 1584227349,
#   'id': 2181997,
#   'main': {'feels_like': 72.5,
#            'humidity': 73,
#            'pressure': 1016,
#            'temp': 70,
#            'temp_max': 70,
#            'temp_min': 70},
#   'name': 'Takaka',
#   'sys': {'country': 'NZ',
#           'id': 2000215,
#           'sunrise': 1584210360,
#           'sunset': 1584254978,
#           'type': 3},
#   'timezone': 46800,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 98, 'gust': 3, 'speed': 1.99}},
#  {'base': 'stations',
#   'clouds': {'all': 55},
#   'cod': 200,
#   'coord': {'lat': 44.02, 'lon': 87.32},
#   'dt': 1584227350,
#   'id': 1529569,
#   'main': {'feels_like': 25.5,
#            'humidity': 69,
#            'pressure': 1026,
#            'temp': 33.8,
#            'temp_max': 33.8,
#            'temp_min': 33.8},
#   'name': 'Changji',
#   'sys': {'country': 'CN',
#           'id': 9677,
#           'sunrise': 1584231778,
#           'sunset': 1584274582,
#           'type': 1},
#   'timezone': 28800,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 160, 'speed': 6.71}}]

# %%
temperatures = []

for temp in response["temp"]:
    t = requests.get(temp).json()
    temperature.append(t)
    
    
#print(temperature)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-39-1f10fff25988> in <module>
#       1 temperatures = []
#       2
# ----> 3 for temp in response["temp"]:
#       4     t = requests.get(temp).json()
#       5     temperature.append(t)
#
# KeyError: 'temp'
