# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
#from api_keys import weather_api_key

api_key = "e691821b9a45feb5f99b41ad777d4ed5"

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 610

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"

api_key = "e691821b9a45feb5f99b41ad777d4ed5"

units = "imperial"

responses = []

weather_url = f"{url}appid={api_key}&units={units}&q="

for city in cities:
    response = requests.get(weather_url + city).json()
    responses.append(response)

# %%
pprint(responses)
# Out:
# [{'base': 'stations',
#   'clouds': {'all': 88},
#   'cod': 200,
#   'coord': {'lat': 3.07, 'lon': 172.79},
#   'dt': 1584170768,
#   'id': 2110227,
#   'main': {'feels_like': 87.82,
#            'grnd_level': 1007,
#            'humidity': 70,
#            'pressure': 1007,
#            'sea_level': 1007,
#            'temp': 83.88,
#            'temp_max': 83.88,
#            'temp_min': 83.88},
#   'name': 'Butaritari',
#   'sys': {'country': 'KI', 'sunrise': 1584124522, 'sunset': 1584168056},
#   'timezone': 43200,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 167, 'speed': 9.37}},
#  {'base': 'stations',
#   'clouds': {'all': 5},
#   'cod': 200,
#   'coord': {'lat': 62.46, 'lon': -114.35},
#   'dt': 1584170651,
#   'id': 6185377,
#   'main': {'feels_like': -32.85,
#            'humidity': 82,
#            'pressure': 1044,
#            'temp': -22,
#            'temp_max': -22,
#            'temp_min': -22},
#   'name': 'Yellowknife',
#   'sys': {'country': 'CA',
#           'id': 1007,
#           'sunrise': 1584194181,
#           'sunset': 1584236196,
#           'type': 1},
#   'timezone': -21600,
#   'visibility': 24140,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 170, 'speed': 6.93}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 22.08, 'lon': -159.32},
#   'dt': 1584170768,
#   'id': 5848280,
#   'main': {'feels_like': 69.37,
#            'humidity': 73,
#            'pressure': 1017,
#            'temp': 68.81,
#            'temp_max': 71.6,
#            'temp_min': 64.99},
#   'name': 'Kapaa',
#   'sys': {'country': 'US',
#           'id': 7873,
#           'sunrise': 1584118032,
#           'sunset': 1584161162,
#           'type': 1},
#   'timezone': -36000,
#   'visibility': 16093,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 280, 'speed': 4.7}},
#  {'base': 'stations',
#   'clouds': {'all': 89},
#   'cod': 200,
#   'coord': {'lat': -16.48, 'lon': -151.75},
#   'dt': 1584170768,
#   'id': 4034551,
#   'main': {'feels_like': 84.97,
#            'grnd_level': 1012,
#            'humidity': 79,
#            'pressure': 1013,
#            'sea_level': 1013,
#            'temp': 83.1,
#            'temp_max': 83.1,
#            'temp_min': 83.1},
#   'name': 'Faanui',
#   'sys': {'country': 'PF', 'sunrise': 1584115789, 'sunset': 1584159771},
#   'timezone': -36000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 113, 'speed': 16.02}},
#  {'base': 'stations',
#   'clouds': {'all': 3},
#   'cod': 200,
#   'coord': {'lat': 14.69, 'lon': -17.44},
#   'dt': 1584170506,
#   'id': 2253354,
#   'main': {'feels_like': 75.02,
#            'humidity': 94,
#            'pressure': 1011,
#            'temp': 70.63,
#            'temp_max': 71.6,
#            'temp_min': 69.8},
#   'name': 'Dakar',
#   'sys': {'country': 'SN',
#           'id': 2419,
#           'sunrise': 1584170275,
#           'sunset': 1584213594,
#           'type': 1},
#   'timezone': 0,
#   'visibility': 8000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 360, 'speed': 4.7}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 71.29, 'lon': -156.79},
#   'dt': 1584170768,
#   'id': 5880054,
#   'main': {'feels_like': 3.63,
#            'humidity': 85,
#            'pressure': 1016,
#            'temp': 24.8,
#            'temp_max': 24.8,
#            'temp_min': 24.8},
#   'name': 'Barrow',
#   'sys': {'country': 'US',
#           'id': 7649,
#           'sunrise': 1584118593,
#           'sunset': 1584159386,
#           'type': 1},
#   'timezone': -28800,
#   'visibility': 2414,
#   'weather': [{'description': 'light snow',
#                'icon': '13n',
#                'id': 600,
#                'main': 'Snow'},
#               {'description': 'mist',
#                'icon': '50n',
#                'id': 701,
#                'main': 'Mist'}],
#   'wind': {'deg': 230, 'gust': 40.26, 'speed': 28.86}},
#  {'base': 'stations',
#   'clouds': {'all': 19},
#   'cod': 200,
#   'coord': {'lat': -23.12, 'lon': -134.97},
#   'dt': 1584170769,
#   'id': 4030556,
#   'main': {'feels_like': 78.21,
#            'grnd_level': 1015,
#            'humidity': 76,
#            'pressure': 1015,
#            'sea_level': 1015,
#            'temp': 77.04,
#            'temp_max': 77.04,
#            'temp_min': 77.04},
#   'name': 'Rikitea',
#   'sys': {'country': 'PF', 'sunrise': 1584111671, 'sunset': 1584155837},
#   'timezone': -32400,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 144, 'speed': 10.49}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -33.65, 'lon': 115.33},
#   'dt': 1584170769,
#   'id': 2075265,
#   'main': {'feels_like': 81.21,
#            'humidity': 52,
#            'pressure': 1010,
#            'temp': 79.09,
#            'temp_max': 80.01,
#            'temp_min': 78.01},
#   'name': 'Busselton',
#   'rain': {'3h': 2.25},
#   'sys': {'country': 'AU',
#           'id': 2020551,
#           'sunrise': 1584137841,
#           'sunset': 1584182312,
#           'type': 3},
#   'timezone': 28800,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 77, 'gust': 3, 'speed': 1.99}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 6},
#   'cod': 200,
#   'coord': {'lat': -46.19, 'lon': 168.86},
#   'dt': 1584170769,
#   'id': 6201424,
#   'main': {'feels_like': 63.18,
#            'humidity': 73,
#            'pressure': 1015,
#            'temp': 63,
#            'temp_max': 63,
#            'temp_min': 63},
#   'name': 'Mataura',
#   'sys': {'country': 'NZ',
#           'id': 2008959,
#           'sunrise': 1584124709,
#           'sunset': 1584169755,
#           'type': 3},
#   'timezone': 46800,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 49, 'gust': 3, 'speed': 1.99}},
#  {'base': 'stations',
#   'clouds': {'all': 83},
#   'cod': 200,
#   'coord': {'lat': 36.62, 'lon': 101.77},
#   'dt': 1584170769,
#   'id': 1788852,
#   'main': {'feels_like': 35.67,
#            'grnd_level': 761,
#            'humidity': 19,
#            'pressure': 1018,
#            'sea_level': 1018,
#            'temp': 43.2,
#            'temp_max': 43.2,
#            'temp_min': 43.2},
#   'name': 'Xining',
#   'sys': {'country': 'CN', 'sunrise': 1584141921, 'sunset': 1584184739},
#   'timezone': 28800,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 26, 'speed': 2.48}},
#  {'base': 'stations',
#   'clouds': {'all': 67},
#   'cod': 200,
#   'coord': {'lat': 71.92, 'lon': 114.08},
#   'dt': 1584170769,
#   'id': 2017155,
#   'main': {'feels_like': -29.04,
#            'grnd_level': 986,
#            'humidity': 87,
#            'pressure': 997,
#            'sea_level': 997,
#            'temp': -9.31,
#            'temp_max': -9.31,
#            'temp_min': -9.31},
#   'name': 'Saskylakh',
#   'sys': {'country': 'RU', 'sunrise': 1584139955, 'sunset': 1584180798},
#   'timezone': 32400,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 156, 'speed': 23.13}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -28.57, 'lon': -70.76},
#   'dt': 1584170770,
#   'id': 3868633,
#   'main': {'feels_like': 59.97,
#            'grnd_level': 955,
#            'humidity': 76,
#            'pressure': 1015,
#            'sea_level': 1015,
#            'temp': 60.1,
#            'temp_max': 60.1,
#            'temp_min': 60.1},
#   'name': 'Vallenar',
#   'sys': {'country': 'CL', 'sunrise': 1584182605, 'sunset': 1584226853},
#   'timezone': -10800,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 335, 'speed': 1.61}},
#  {'base': 'stations',
#   'clouds': {'all': 67},
#   'cod': 200,
#   'coord': {'lat': -24.79, 'lon': -50.01},
#   'dt': 1584170770,
#   'id': 3466704,
#   'main': {'feels_like': 55.96,
#            'grnd_level': 908,
#            'humidity': 90,
#            'pressure': 1018,
#            'sea_level': 1018,
#            'temp': 56.95,
#            'temp_max': 56.95,
#            'temp_min': 56.95},
#   'name': 'Castro',
#   'sys': {'country': 'BR', 'sunrise': 1584177676, 'sunset': 1584221824},
#   'timezone': -10800,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 73, 'speed': 3.98}},
#  {'base': 'stations',
#   'clouds': {'all': 96},
#   'cod': 200,
#   'coord': {'lat': 65.61, 'lon': -37.64},
#   'dt': 1584170770,
#   'id': 3424607,
#   'main': {'feels_like': -0.29,
#            'humidity': 71,
#            'pressure': 1011,
#            'temp': 8.6,
#            'temp_max': 8.6,
#            'temp_min': 8.6},
#   'name': 'Tasiilaq',
#   'sys': {'country': 'GL',
#           'id': 81,
#           'sunrise': 1584175921,
#           'sunset': 1584217642,
#           'type': 1},
#   'timezone': -10800,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 180, 'speed': 4.7}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 99},
#   'cod': 200,
#   'coord': {'lat': -10.61, 'lon': 34.11},
#   'dt': 1584170770,
#   'id': 927856,
#   'main': {'feels_like': 68.43,
#            'grnd_level': 831,
#            'humidity': 94,
#            'pressure': 1016,
#            'sea_level': 1016,
#            'temp': 65.28,
#            'temp_max': 65.28,
#            'temp_min': 65.28},
#   'name': 'Livingstonia',
#   'rain': {'3h': 1.63},
#   'sys': {'country': 'MW', 'sunrise': 1584157655, 'sunset': 1584201476},
#   'timezone': 7200,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 107, 'speed': 2.68}},
#  {'base': 'stations',
#   'clouds': {'all': 62},
#   'cod': 200,
#   'coord': {'lat': -0.74, 'lon': -90.35},
#   'dt': 1584170770,
#   'id': 3652764,
#   'main': {'feels_like': 84,
#            'humidity': 87,
#            'pressure': 1011,
#            'temp': 75.99,
#            'temp_max': 75.99,
#            'temp_min': 75.99},
#   'name': 'Puerto Ayora',
#   'sys': {'country': 'EC',
#           'id': 2005652,
#           'sunrise': 1584187623,
#           'sunset': 1584231236,
#           'type': 3},
#   'timezone': -21600,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 32, 'gust': 1.99, 'speed': 1.01}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 65.28, 'lon': -126.83},
#   'dt': 1584170770,
#   'id': 6089245,
#   'main': {'feels_like': -5.76,
#            'humidity': 84,
#            'pressure': 1032,
#            'temp': 3.2,
#            'temp_max': 3.2,
#            'temp_min': 3.2},
#   'name': 'Norman Wells',
#   'sys': {'country': 'CA',
#           'id': 951,
#           'sunrise': 1584197259,
#           'sunset': 1584239107,
#           'type': 1},
#   'timezone': -21600,
#   'visibility': 48279,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 270, 'speed': 4.7}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 78},
#   'cod': 200,
#   'coord': {'lat': -53.15, 'lon': -70.92},
#   'dt': 1584170611,
#   'id': 3874787,
#   'main': {'feels_like': 36.97,
#            'humidity': 66,
#            'pressure': 1004,
#            'temp': 51.44,
#            'temp_max': 51.8,
#            'temp_min': 51.01},
#   'name': 'Punta Arenas',
#   'sys': {'country': 'CL',
#           'id': 8487,
#           'sunrise': 1584182106,
#           'sunset': 1584227429,
#           'type': 1},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 290, 'speed': 21.92}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 5.41, 'lon': 100.34},
#   'dt': 1584170771,
#   'id': 1735106,
#   'main': {'feels_like': 101.52,
#            'humidity': 63,
#            'pressure': 1007,
#            'temp': 92.95,
#            'temp_max': 93.2,
#            'temp_min': 91},
#   'name': 'George Town',
#   'sys': {'country': 'MY',
#           'id': 9429,
#           'sunrise': 1584141929,
#           'sunset': 1584185418,
#           'type': 1},
#   'timezone': 28800,
#   'visibility': 9000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02d',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 270, 'speed': 6.93}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 34.67, 'lon': 138.95},
#   'dt': 1584170771,
#   'id': 1852357,
#   'main': {'feels_like': 23.94,
#            'humidity': 87,
#            'pressure': 1004,
#            'temp': 39.81,
#            'temp_max': 42.8,
#            'temp_min': 35.01},
#   'name': 'Shimoda',
#   'sys': {'country': 'JP',
#           'id': 8070,
#           'sunrise': 1584132982,
#           'sunset': 1584175836,
#           'type': 1},
#   'timezone': 32400,
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 30, 'speed': 23.04}},
#  {'base': 'stations',
#   'clouds': {'all': 60},
#   'cod': 200,
#   'coord': {'lat': 3.52, 'lon': 39.06},
#   'dt': 1584170771,
#   'id': 186180,
#   'main': {'feels_like': 77.86,
#            'grnd_level': 916,
#            'humidity': 62,
#            'pressure': 1014,
#            'sea_level': 1014,
#            'temp': 78.66,
#            'temp_max': 78.66,
#            'temp_min': 78.66},
#   'name': 'Moyale',
#   'sys': {'country': 'KE', 'sunrise': 1584156613, 'sunset': 1584200142},
#   'timezone': 10800,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 127, 'speed': 10.42}},
#  {'base': 'stations',
#   'clouds': {'all': 4},
#   'cod': 200,
#   'coord': {'lat': -21.21, 'lon': -159.78},
#   'dt': 1584170771,
#   'id': 4035715,
#   'main': {'feels_like': 86.18,
#            'humidity': 94,
#            'pressure': 1015,
#            'temp': 77,
#            'temp_max': 77,
#            'temp_min': 77},
#   'name': 'Avarua',
#   'sys': {'country': 'CK',
#           'id': 7271,
#           'sunrise': 1584117654,
#           'sunset': 1584161760,
#           'type': 1},
#   'timezone': -36000,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 180, 'speed': 2.24}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 30.8, 'lon': 106.08},
#   'dt': 1584170772,
#   'id': 1800146,
#   'main': {'feels_like': 61.92,
#            'grnd_level': 979,
#            'humidity': 32,
#            'pressure': 1022,
#            'sea_level': 1022,
#            'temp': 68.14,
#            'temp_max': 68.14,
#            'temp_min': 68.14},
#   'name': 'Nanchong',
#   'sys': {'country': 'CN', 'sunrise': 1584140817, 'sunset': 1584183775},
#   'timezone': 28800,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 85, 'speed': 6.2}},
#  {'base': 'stations',
#   'clouds': {'all': 4},
#   'cod': 200,
#   'coord': {'lat': -37.62, 'lon': -73.65},
#   'dt': 1584170772,
#   'id': 3883457,
#   'main': {'feels_like': 43.45,
#            'grnd_level': 1003,
#            'humidity': 93,
#            'pressure': 1021,
#            'sea_level': 1021,
#            'temp': 47.19,
#            'temp_max': 47.19,
#            'temp_min': 47.19},
#   'name': 'Lebu',
#   'sys': {'country': 'CL', 'sunrise': 1584183151, 'sunset': 1584227694},
#   'timezone': -10800,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 176, 'speed': 4.7}},
#  {'base': 'stations',
#   'clouds': {'all': 56},
#   'cod': 200,
#   'coord': {'lat': 64.75, 'lon': 177.48},
#   'dt': 1584170772,
#   'id': 2127202,
#   'main': {'feels_like': 3.51,
#            'humidity': 66,
#            'pressure': 1022,
#            'temp': 15.8,
#            'temp_max': 15.8,
#            'temp_min': 15.8},
#   'name': 'Anadyr',
#   'sys': {'country': 'RU',
#           'id': 8872,
#           'sunrise': 1584124391,
#           'sunset': 1584165935,
#           'type': 1},
#   'timezone': 43200,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 170, 'gust': 13.42, 'speed': 11.18}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 28.12, 'lon': -16.73},
#   'dt': 1584170772,
#   'id': 2522437,
#   'main': {'feels_like': 50.74,
#            'humidity': 67,
#            'pressure': 1018,
#            'temp': 59.49,
#            'temp_max': 64,
#            'temp_min': 55.4},
#   'name': 'Adeje',
#   'sys': {'country': 'ES',
#           'id': 2373,
#           'sunrise': 1584170237,
#           'sunset': 1584213291,
#           'type': 1},
#   'timezone': 0,
#   'visibility': 10000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02d',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 50, 'speed': 14.99}},
#  {'base': 'stations',
#   'clouds': {'all': 28},
#   'cod': 200,
#   'coord': {'lat': -34.53, 'lon': 20.04},
#   'dt': 1584170772,
#   'id': 1015776,
#   'main': {'feels_like': 64.06,
#            'humidity': 68,
#            'pressure': 1015,
#            'temp': 67.24,
#            'temp_max': 68,
#            'temp_min': 66},
#   'name': 'Bredasdorp',
#   'sys': {'country': 'ZA',
#           'id': 1966,
#           'sunrise': 1584160707,
#           'sunset': 1584205175,
#           'type': 1},
#   'timezone': 7200,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 310, 'speed': 9.17}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 57.79, 'lon': -152.41},
#   'dt': 1584170773,
#   'id': 5866583,
#   'main': {'feels_like': 17.67,
#            'humidity': 73,
#            'pressure': 1044,
#            'temp': 24.8,
#            'temp_max': 24.8,
#            'temp_min': 24.8},
#   'name': 'Saint Paul Harbor',
#   'sys': {'country': 'US',
#           'id': 7668,
#           'sunrise': 1584116947,
#           'sunset': 1584158930,
#           'type': 1},
#   'timezone': -28800,
#   'visibility': 16093,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 270, 'speed': 3.36}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -12.93, 'lon': 45.15},
#   'dt': 1584170773,
#   'id': 1090415,
#   'main': {'feels_like': 94.28,
#            'humidity': 70,
#            'pressure': 1011,
#            'temp': 89.6,
#            'temp_max': 89.6,
#            'temp_min': 89.6},
#   'name': 'Chirongui',
#   'rain': {'3h': 0.19},
#   'sys': {'country': 'YT',
#           'id': 2131,
#           'sunrise': 1584154979,
#           'sunset': 1584198853,
#           'type': 1},
#   'timezone': 10800,
#   'visibility': 10000,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 260, 'speed': 13.87}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -20.28, 'lon': 44.28},
#   'dt': 1584170773,
#   'id': 1058381,
#   'main': {'feels_like': 84.67,
#            'grnd_level': 1003,
#            'humidity': 61,
#            'pressure': 1011,
#            'sea_level': 1011,
#            'temp': 81.99,
#            'temp_max': 81.99,
#            'temp_min': 81.99},
#   'name': 'Morondava',
#   'sys': {'country': 'MG', 'sunrise': 1584155100, 'sunset': 1584199150},
#   'timezone': 10800,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 101, 'speed': 6.38}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -54.8, 'lon': -68.3},
#   'dt': 1584170773,
#   'id': 3833367,
#   'main': {'feels_like': 45.52,
#            'humidity': 91,
#            'pressure': 999,
#            'temp': 53.6,
#            'temp_max': 53.6,
#            'temp_min': 53.6},
#   'name': 'Ushuaia',
#   'sys': {'country': 'AR',
#           'id': 8303,
#           'sunrise': 1584181417,
#           'sunset': 1584226860,
#           'type': 1},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 320, 'speed': 14.99}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 44.1, 'lon': 12.41},
#   'dt': 1584170773,
#   'id': 3167030,
#   'main': {'feels_like': 52.45,
#            'humidity': 87,
#            'pressure': 1015,
#            'temp': 53.65,
#            'temp_max': 55,
#            'temp_min': 48.99},
#   'name': 'Savignano sul Rubicone',
#   'sys': {'country': 'IT',
#           'id': 6770,
#           'sunrise': 1584163444,
#           'sunset': 1584206100,
#           'type': 1},
#   'timezone': 3600,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 290, 'speed': 2.24}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -33.93, 'lon': 18.42},
#   'dt': 1584170760,
#   'id': 3369157,
#   'main': {'feels_like': 63.32,
#            'humidity': 82,
#            'pressure': 1016,
#            'temp': 63.93,
#            'temp_max': 64.4,
#            'temp_min': 63},
#   'name': 'Cape Town',
#   'sys': {'country': 'ZA',
#           'id': 1899,
#           'sunrise': 1584161107,
#           'sunset': 1584205553,
#           'type': 1},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 350, 'speed': 5.82}},
#  {'base': 'stations',
#   'clouds': {'all': 7},
#   'cod': 200,
#   'coord': {'lat': -34, 'lon': 24.73},
#   'dt': 1584170774,
#   'id': 986717,
#   'main': {'feels_like': 66.63,
#            'grnd_level': 982,
#            'humidity': 82,
#            'pressure': 1013,
#            'sea_level': 1013,
#            'temp': 67.33,
#            'temp_max': 67.33,
#            'temp_min': 67.33},
#   'name': 'Kruisfontein',
#   'sys': {'country': 'ZA', 'sunrise': 1584159590, 'sunset': 1584204042},
#   'timezone': 7200,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 260, 'speed': 8.16}},
#  {'base': 'stations',
#   'clouds': {'all': 97},
#   'cod': 200,
#   'coord': {'lat': -14.66, 'lon': 17.69},
#   'dt': 1584170774,
#   'id': 3347353,
#   'main': {'feels_like': 66.18,
#            'grnd_level': 854,
#            'humidity': 92,
#            'pressure': 1014,
#            'sea_level': 1014,
#            'temp': 64.53,
#            'temp_max': 64.53,
#            'temp_min': 64.53},
#   'name': 'Menongue',
#   'sys': {'country': 'AO', 'sunrise': 1584161550, 'sunset': 1584205460},
#   'timezone': 3600,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 71, 'speed': 4.34}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': -38.27, 'lon': 141.97},
#   'dt': 1584170774,
#   'id': 2171099,
#   'main': {'feels_like': 47.93,
#            'grnd_level': 1025,
#            'humidity': 66,
#            'pressure': 1025,
#            'sea_level': 1025,
#            'temp': 57.58,
#            'temp_max': 57.58,
#            'temp_min': 57.58},
#   'name': 'Codrington',
#   'sys': {'country': 'AU', 'sunrise': 1584131355, 'sunset': 1584176013},
#   'timezone': 39600,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 158, 'speed': 15.59}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 60.14, 'lon': -45.24},
#   'dt': 1584170774,
#   'id': 3421765,
#   'main': {'feels_like': 8.94,
#            'grnd_level': 1005,
#            'humidity': 72,
#            'pressure': 1012,
#            'sea_level': 1012,
#            'temp': 23.16,
#            'temp_max': 23.16,
#            'temp_min': 23.16},
#   'name': 'Nanortalik',
#   'sys': {'country': 'GL', 'sunrise': 1584177567, 'sunset': 1584219644},
#   'timezone': -10800,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 311, 'speed': 15.68}},
#  {'base': 'stations',
#   'clouds': {'all': 91},
#   'cod': 200,
#   'coord': {'lat': 51.03, 'lon': -4.22},
#   'dt': 1584170774,
#   'id': 2641434,
#   'main': {'feels_like': 40.41,
#            'humidity': 98,
#            'pressure': 1012,
#            'temp': 45.05,
#            'temp_max': 46.99,
#            'temp_min': 43},
#   'name': 'Northam',
#   'rain': {'3h': 0.38},
#   'sys': {'country': 'GB',
#           'id': 2005965,
#           'sunrise': 1584167541,
#           'sunset': 1584209984,
#           'type': 3},
#   'timezone': 0,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 232, 'gust': 13, 'speed': 5.99}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': -33.92, 'lon': 25.57},
#   'dt': 1584170775,
#   'id': 964420,
#   'main': {'feels_like': 63.3,
#            'humidity': 93,
#            'pressure': 1013,
#            'temp': 66.2,
#            'temp_max': 66.2,
#            'temp_min': 66.2},
#   'name': 'Port Elizabeth',
#   'sys': {'country': 'ZA',
#           'id': 1973,
#           'sunrise': 1584159390,
#           'sunset': 1584203839,
#           'type': 1},
#   'timezone': 7200,
#   'visibility': 7000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 250, 'speed': 13.87}},
#  {'base': 'stations',
#   'clouds': {'all': 1},
#   'cod': 200,
#   'coord': {'lat': 42.1, 'lon': -79.24},
#   'dt': 1584170775,
#   'id': 5122534,
#   'main': {'feels_like': 19.06,
#            'humidity': 74,
#            'pressure': 1025,
#            'temp': 32.02,
#            'temp_max': 35.01,
#            'temp_min': 30.2},
#   'name': 'Jamestown',
#   'sys': {'country': 'US',
#           'id': 4588,
#           'sunrise': 1584185386,
#           'sunset': 1584228142,
#           'type': 1},
#   'timezone': -14400,
#   'visibility': 16093,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 300, 'gust': 21.92, 'speed': 14.99}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -42.88, 'lon': 147.33},
#   'dt': 1584170775,
#   'id': 2163355,
#   'main': {'feels_like': 47.41,
#            'humidity': 54,
#            'pressure': 1020,
#            'temp': 57.81,
#            'temp_max': 62.01,
#            'temp_min': 53.01},
#   'name': 'Hobart',
#   'sys': {'country': 'AU',
#           'id': 9545,
#           'sunrise': 1584129965,
#           'sunset': 1584174830,
#           'type': 1},
#   'timezone': 39600,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 240, 'speed': 14.99}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 68.75, 'lon': 161.3},
#   'dt': 1584170775,
#   'id': 2126199,
#   'main': {'feels_like': -21.12,
#            'grnd_level': 1016,
#            'humidity': 95,
#            'pressure': 1017,
#            'sea_level': 1017,
#            'temp': -10.88,
#            'temp_max': -10.88,
#            'temp_min': -10.88},
#   'name': 'Cherskiy',
#   'sys': {'country': 'RU', 'sunrise': 1584128456, 'sunset': 1584169635},
#   'timezone': 39600,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 228, 'speed': 6.31}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 0.2, 'lon': 30},
#   'dt': 1584170775,
#   'id': 231250,
#   'main': {'feels_like': 76.03,
#            'grnd_level': 897,
#            'humidity': 72,
#            'pressure': 1016,
#            'sea_level': 1016,
#            'temp': 72.23,
#            'temp_max': 72.23,
#            'temp_min': 72.23},
#   'name': 'Kilembe',
#   'sys': {'country': 'UG', 'sunrise': 1584158754, 'sunset': 1584202349},
#   'timezone': 10800,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 116, 'speed': 0.94}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 52.79, 'lon': 89.9},
#   'dt': 1584170775,
#   'id': 1490036,
#   'main': {'feels_like': 26.92,
#            'grnd_level': 948,
#            'humidity': 100,
#            'pressure': 1020,
#            'sea_level': 1020,
#            'temp': 32.56,
#            'temp_max': 32.56,
#            'temp_min': 32.56},
#   'name': 'Tashtyp',
#   'sys': {'country': 'RU', 'sunrise': 1584145023, 'sunset': 1584187334},
#   'timezone': 25200,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 217, 'speed': 3.8}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 32.63, 'lon': -16.85},
#   'dt': 1584170776,
#   'id': 2270258,
#   'main': {'feels_like': 50.99,
#            'humidity': 59,
#            'pressure': 1022,
#            'temp': 59.34,
#            'temp_max': 60.8,
#            'temp_min': 57.99},
#   'name': 'Caniço',
#   'sys': {'country': 'PT',
#           'id': 6894,
#           'sunrise': 1584170315,
#           'sunset': 1584213272,
#           'type': 1},
#   'timezone': 0,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 20, 'speed': 12.75}},
#  {'base': 'stations',
#   'clouds': {'all': 16},
#   'cod': 200,
#   'coord': {'lat': 10.07, 'lon': 34.53},
#   'dt': 1584170776,
#   'id': 343292,
#   'main': {'feels_like': 76.48,
#            'grnd_level': 883,
#            'humidity': 22,
#            'pressure': 1013,
#            'sea_level': 1013,
#            'temp': 82.06,
#            'temp_max': 82.06,
#            'temp_min': 82.06},
#   'name': 'Āsosa',
#   'sys': {'country': 'ET', 'sunrise': 1584157764, 'sunset': 1584201165},
#   'timezone': 10800,
#   'weather': [{'description': 'few clouds',
#                'icon': '02d',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 72, 'speed': 5.77}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 14},
#   'cod': 200,
#   'coord': {'lat': -35.33, 'lon': -72.42},
#   'dt': 1584170776,
#   'id': 3893726,
#   'main': {'feels_like': 54.55,
#            'grnd_level': 1000,
#            'humidity': 77,
#            'pressure': 1017,
#            'sea_level': 1017,
#            'temp': 57.58,
#            'temp_max': 57.58,
#            'temp_min': 57.58},
#   'name': 'Constitución',
#   'sys': {'country': 'CL', 'sunrise': 1584182896, 'sunset': 1584227358},
#   'timezone': -10800,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 160, 'speed': 5.73}},
#  {'base': 'stations',
#   'clouds': {'all': 48},
#   'cod': 200,
#   'coord': {'lat': -12.04, 'lon': -77.03},
#   'dt': 1584170615,
#   'id': 3936456,
#   'main': {'feels_like': 75.69,
#            'humidity': 88,
#            'pressure': 1011,
#            'temp': 73.4,
#            'temp_max': 73.4,
#            'temp_min': 73.4},
#   'name': 'Lima',
#   'sys': {'country': 'PE',
#           'id': 8682,
#           'sunrise': 1584184314,
#           'sunset': 1584228153,
#           'type': 1},
#   'timezone': -18000,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 160, 'speed': 9.17}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 26.77, 'lon': 31.5},
#   'dt': 1584170776,
#   'id': 347634,
#   'main': {'feels_like': 48.54,
#            'humidity': 45,
#            'pressure': 1016,
#            'temp': 61.7,
#            'temp_max': 62.6,
#            'temp_min': 60.8},
#   'name': 'Ţahţā',
#   'sys': {'country': 'EG',
#           'id': 2548,
#           'sunrise': 1584158657,
#           'sunset': 1584201726,
#           'type': 1},
#   'timezone': 7200,
#   'visibility': 6000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 280, 'speed': 19.46}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': -34.58, 'lon': 150.86},
#   'dt': 1584170776,
#   'id': 6255012,
#   'main': {'feels_like': 50.36,
#            'humidity': 59,
#            'pressure': 1019,
#            'temp': 61.39,
#            'temp_max': 63,
#            'temp_min': 57.99},
#   'name': 'Flinders',
#   'sys': {'country': 'AU',
#           'id': 9594,
#           'sunrise': 1584129292,
#           'sunset': 1584173810,
#           'type': 1},
#   'timezone': 39600,
#   'visibility': 10000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 170, 'speed': 18.34}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 66, 'lon': 111.5},
#   'dt': 1584170777,
#   'id': 2027296,
#   'main': {'feels_like': -7.76,
#            'humidity': 65,
#            'pressure': 999,
#            'temp': 5,
#            'temp_max': 5,
#            'temp_min': 5},
#   'name': 'Aykhal',
#   'sys': {'country': 'RU',
#           'id': 8846,
#           'sunrise': 1584140238,
#           'sunset': 1584181752,
#           'type': 1},
#   'timezone': 32400,
#   'visibility': 10000,
#   'weather': [{'description': 'light snow',
#                'icon': '13d',
#                'id': 600,
#                'main': 'Snow'}],
#   'wind': {'deg': 150, 'speed': 11.18}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 49.17, 'lon': -101.8},
#   'dt': 1584170777,
#   'id': 5917349,
#   'main': {'feels_like': -2.58,
#            'humidity': 80,
#            'pressure': 1039,
#            'temp': 7,
#            'temp_max': 7,
#            'temp_min': 7},
#   'name': 'Carnduff',
#   'sys': {'country': 'CA',
#           'id': 2005015,
#           'sunrise': 1584190894,
#           'sunset': 1584233460,
#           'type': 3},
#   'timezone': -21600,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 68, 'speed': 5.99}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 12.67, 'lon': -0.58},
#   'dt': 1584170777,
#   'id': 2361946,
#   'main': {'feels_like': 63.34,
#            'grnd_level': 975,
#            'humidity': 12,
#            'pressure': 1010,
#            'sea_level': 1010,
#            'temp': 74.43,
#            'temp_max': 74.43,
#            'temp_min': 74.43},
#   'name': 'Boulsa',
#   'sys': {'country': 'BF', 'sunrise': 1584166212, 'sunset': 1584209567},
#   'timezone': 0,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 93, 'speed': 10.58}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 69.65, 'lon': 18.96},
#   'dt': 1584170777,
#   'id': 6453316,
#   'main': {'feels_like': 10.13,
#            'humidity': 92,
#            'pressure': 1005,
#            'temp': 17.6,
#            'temp_max': 17.6,
#            'temp_min': 17.6},
#   'name': 'Tromsø',
#   'sys': {'country': 'NO',
#           'id': 1681,
#           'sunrise': 1584162562,
#           'sunset': 1584203839,
#           'type': 1},
#   'timezone': 3600,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 263, 'speed': 3.71}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 27.93, 'lon': -110.9},
#   'dt': 1584170742,
#   'id': 4005143,
#   'main': {'feels_like': 65.05,
#            'grnd_level': 1007,
#            'humidity': 60,
#            'pressure': 1018,
#            'sea_level': 1018,
#            'temp': 65.57,
#            'temp_max': 65.57,
#            'temp_min': 65.57},
#   'name': 'Guaymas',
#   'sys': {'country': 'MX', 'sunrise': 1584192818, 'sunset': 1584235903},
#   'timezone': -25200,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 324, 'speed': 1.72}},
#  {'base': 'stations',
#   'clouds': {'all': 14},
#   'cod': 200,
#   'coord': {'lat': -0.6, 'lon': 73.08},
#   'dt': 1584170777,
#   'id': 1282256,
#   'main': {'feels_like': 86.92,
#            'grnd_level': 1012,
#            'humidity': 57,
#            'pressure': 1012,
#            'sea_level': 1012,
#            'temp': 83.8,
#            'temp_max': 83.8,
#            'temp_min': 83.8},
#   'name': 'Hithadhoo',
#   'sys': {'country': 'MV', 'sunrise': 1584148409, 'sunset': 1584192020},
#   'timezone': 18000,
#   'weather': [{'description': 'few clouds',
#                'icon': '02d',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 96, 'speed': 5.39}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 42.6, 'lon': -73.97},
#   'dt': 1584170778,
#   'id': 5106841,
#   'main': {'feels_like': 22.32,
#            'humidity': 44,
#            'pressure': 1020,
#            'temp': 36.66,
#            'temp_max': 41,
#            'temp_min': 32},
#   'name': 'Albany',
#   'sys': {'country': 'US',
#           'id': 3273,
#           'sunrise': 1584184129,
#           'sunset': 1584226869,
#           'type': 1},
#   'timezone': -14400,
#   'visibility': 16093,
#   'weather': [{'description': 'few clouds',
#                'icon': '02n',
#                'id': 801,
#                'main': 'Clouds'}],
#   'wind': {'deg': 280, 'gust': 32.21, 'speed': 16.11}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 35.73, 'lon': 140.83},
#   'dt': 1584170778,
#   'id': 2112802,
#   'main': {'feels_like': 27.46,
#            'humidity': 100,
#            'pressure': 1005,
#            'temp': 37.36,
#            'temp_max': 39.2,
#            'temp_min': 35.6},
#   'name': 'Hasaki',
#   'sys': {'country': 'JP',
#           'id': 7955,
#           'sunrise': 1584132544,
#           'sunset': 1584175371,
#           'type': 1},
#   'timezone': 32400,
#   'visibility': 8000,
#   'weather': [{'description': 'light rain',
#                'icon': '10d',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 10, 'speed': 12.75}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 71.97, 'lon': 102.5},
#   'dt': 1584170778,
#   'id': 2022572,
#   'main': {'feels_like': -6.75,
#            'grnd_level': 980,
#            'humidity': 94,
#            'pressure': 983,
#            'sea_level': 983,
#            'temp': 6.49,
#            'temp_max': 6.49,
#            'temp_min': 6.49},
#   'name': 'Khatanga',
#   'snow': {'3h': 1.56},
#   'sys': {'country': 'RU', 'sunrise': 1584142728, 'sunset': 1584183582},
#   'timezone': 25200,
#   'weather': [{'description': 'snow',
#                'icon': '13d',
#                'id': 601,
#                'main': 'Snow'}],
#   'wind': {'deg': 195, 'speed': 12.75}},
#  {'base': 'stations',
#   'clouds': {'all': 69},
#   'cod': 200,
#   'coord': {'lat': 39.05, 'lon': -27.98},
#   'dt': 1584170778,
#   'id': 3372964,
#   'main': {'feels_like': 55.83,
#            'grnd_level': 1029,
#            'humidity': 73,
#            'pressure': 1029,
#            'sea_level': 1029,
#            'temp': 60.04,
#            'temp_max': 60.04,
#            'temp_min': 60.04},
#   'name': 'Lagoa',
#   'sys': {'country': 'PT', 'sunrise': 1584173059, 'sunset': 1584215869},
#   'timezone': -3600,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04n',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 226, 'speed': 8.28}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -30.18, 'lon': -50.21},
#   'dt': 1584170778,
#   'id': 3466165,
#   'main': {'feels_like': 71.58,
#            'grnd_level': 1015,
#            'humidity': 89,
#            'pressure': 1015,
#            'sea_level': 1015,
#            'temp': 74.88,
#            'temp_max': 74.88,
#            'temp_min': 74.88},
#   'name': 'Cidreira',
#   'sys': {'country': 'BR', 'sunrise': 1584177647, 'sunset': 1584221949},
#   'timezone': -10800,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 34, 'speed': 20.69}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': -9.67, 'lon': -35.74},
#   'dt': 1584170779,
#   'id': 3395981,
#   'main': {'feels_like': 81.97,
#            'humidity': 94,
#            'pressure': 1013,
#            'temp': 75.2,
#            'temp_max': 75.2,
#            'temp_min': 75.2},
#   'name': 'Maceió',
#   'sys': {'country': 'BR',
#           'id': 8413,
#           'sunrise': 1584174429,
#           'sunset': 1584218223,
#           'type': 1},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 100, 'speed': 4.7}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 5.95, 'lon': 80.54},
#   'dt': 1584170779,
#   'id': 1235846,
#   'main': {'feels_like': 97.29,
#            'grnd_level': 1007,
#            'humidity': 36,
#            'pressure': 1012,
#            'sea_level': 1012,
#            'temp': 95.65,
#            'temp_max': 95.65,
#            'temp_min': 95.65},
#   'name': 'Matara',
#   'sys': {'country': 'LK', 'sunrise': 1584146685, 'sunset': 1584190164},
#   'timezone': 19800,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 121, 'speed': 6.02}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': 47.8, 'lon': 67.71},
#   'dt': 1584170779,
#   'id': 1516589,
#   'main': {'feels_like': 28.45,
#            'humidity': 80,
#            'pressure': 1017,
#            'temp': 33.8,
#            'temp_max': 33.8,
#            'temp_min': 33.8},
#   'name': 'Zhezkazgan',
#   'sys': {'country': 'KZ',
#           'id': 8826,
#           'sunrise': 1584150248,
#           'sunset': 1584192758,
#           'type': 1},
#   'timezone': 21600,
#   'visibility': 10000,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'speed': 2.24}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 77.48, 'lon': -69.36},
#   'dt': 1584170779,
#   'id': 3831208,
#   'main': {'feels_like': -32.17,
#            'grnd_level': 978,
#            'humidity': 58,
#            'pressure': 1021,
#            'sea_level': 1021,
#            'temp': -22,
#            'temp_max': -22,
#            'temp_min': -22},
#   'name': 'Qaanaaq',
#   'sys': {'country': 'GL', 'sunrise': 1584184334, 'sunset': 1584224452},
#   'timezone': -10800,
#   'weather': [{'description': 'clear sky',
#                'icon': '01n',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 56, 'speed': 5.57}},
#  {'base': 'stations',
#   'clouds': {'all': 25},
#   'cod': 200,
#   'coord': {'lat': -6.12, 'lon': -76.95},
#   'dt': 1584170779,
#   'id': 3696096,
#   'main': {'feels_like': 67.23,
#            'grnd_level': 906,
#            'humidity': 98,
#            'pressure': 1014,
#            'sea_level': 1014,
#            'temp': 63.48,
#            'temp_max': 63.48,
#            'temp_min': 63.48},
#   'name': 'Jepelacio',
#   'sys': {'country': 'PE', 'sunrise': 1584184355, 'sunset': 1584228073},
#   'timezone': -18000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 133, 'speed': 1.16}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 72.79, 'lon': -56.15},
#   'dt': 1584170779,
#   'id': 3418910,
#   'main': {'feels_like': -21.8,
#            'grnd_level': 1019,
#            'humidity': 97,
#            'pressure': 1020,
#            'sea_level': 1020,
#            'temp': -11.85,
#            'temp_max': -11.85,
#            'temp_min': -11.85},
#   'name': 'Upernavik',
#   'snow': {'3h': 0.13},
#   'sys': {'country': 'GL', 'sunrise': 1584180724, 'sunset': 1584221723},
#   'timezone': -10800,
#   'weather': [{'description': 'light snow',
#                'icon': '13n',
#                'id': 600,
#                'main': 'Snow'}],
#   'wind': {'deg': 352, 'speed': 5.77}},
#  {'base': 'stations',
#   'clouds': {'all': 8},
#   'cod': 200,
#   'coord': {'lat': -34.42, 'lon': 19.23},
#   'dt': 1584170780,
#   'id': 3366880,
#   'main': {'feels_like': 67.75,
#            'humidity': 88,
#            'pressure': 1010,
#            'temp': 64.65,
#            'temp_max': 66,
#            'temp_min': 63},
#   'name': 'Hermanus',
#   'sys': {'country': 'ZA',
#           'id': 2006131,
#           'sunrise': 1584160904,
#           'sunset': 1584205368,
#           'type': 3},
#   'timezone': 7200,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 118, 'gust': 4, 'speed': 1.01}},
#  {'base': 'stations',
#   'clouds': {'all': 92},
#   'cod': 200,
#   'coord': {'lat': 3.17, 'lon': -52.32},
#   'dt': 1584170780,
#   'id': 3382226,
#   'main': {'feels_like': 78.06,
#            'grnd_level': 993,
#            'humidity': 97,
#            'pressure': 1011,
#            'sea_level': 1011,
#            'temp': 71.62,
#            'temp_max': 71.62,
#            'temp_min': 71.62},
#   'name': 'Camopi',
#   'sys': {'country': 'GF', 'sunrise': 1584178535, 'sunset': 1584222074},
#   'timezone': -10800,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 36, 'speed': 2.75}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 33},
#   'cod': 200,
#   'coord': {'lat': -33.01, 'lon': 17.94},
#   'dt': 1584170780,
#   'id': 3361934,
#   'main': {'feels_like': 64.49,
#            'humidity': 77,
#            'pressure': 1015,
#            'temp': 66.2,
#            'temp_max': 66.2,
#            'temp_min': 66.2},
#   'name': 'Saldanha',
#   'sys': {'country': 'ZA',
#           'id': 1943,
#           'sunrise': 1584161238,
#           'sunset': 1584205653,
#           'type': 1},
#   'timezone': 7200,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
# ...
#           'type': 1},
#   'timezone': 10800,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 146, 'speed': 3.56}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 26.18, 'lon': 127.76},
#   'dt': 1584170863,
#   'id': 1855342,
#   'main': {'feels_like': 49.98,
#            'humidity': 63,
#            'pressure': 1014,
#            'temp': 64.85,
#            'temp_max': 66.2,
#            'temp_min': 64.4},
#   'name': 'Nishihara',
#   'sys': {'country': 'JP',
#           'id': 8137,
#           'sunrise': 1584135565,
#           'sunset': 1584178622,
#           'type': 1},
#   'timezone': 32400,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 350, 'speed': 27.51}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 82},
#   'cod': 200,
#   'coord': {'lat': 64.81, 'lon': 25.99},
#   'dt': 1584170864,
#   'id': 645765,
#   'main': {'feels_like': 3.76,
#            'humidity': 72,
#            'pressure': 1004,
#            'temp': 16.75,
#            'temp_max': 18,
#            'temp_min': 15.8},
#   'name': 'Muhos',
#   'sys': {'country': 'FI',
#           'id': 1351,
#           'sunrise': 1584160659,
#           'sunset': 1584202368,
#           'type': 1},
#   'timezone': 7200,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 340, 'speed': 12.75}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 46.19, 'lon': -123.83},
#   'dt': 1584170864,
#   'id': 5711847,
#   'main': {'feels_like': 29.3,
#            'humidity': 80,
#            'pressure': 1002,
#            'temp': 37.44,
#            'temp_max': 39.99,
#            'temp_min': 34},
#   'name': 'Astoria',
#   'sys': {'country': 'US',
#           'id': 3328,
#           'sunrise': 1584196129,
#           'sunset': 1584238797,
#           'type': 1},
#   'timezone': -25200,
#   'visibility': 16093,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 60, 'speed': 8.05}},
#  {'base': 'stations',
#   'clouds': {'all': 66},
#   'cod': 200,
#   'coord': {'lat': -1.57, 'lon': 9.26},
#   'dt': 1584170864,
#   'id': 2396853,
#   'main': {'feels_like': 87.71,
#            'grnd_level': 1006,
#            'humidity': 94,
#            'pressure': 1010,
#            'sea_level': 1010,
#            'temp': 77.32,
#            'temp_max': 77.32,
#            'temp_min': 77.32},
#   'name': 'Omboué',
#   'sys': {'country': 'GA', 'sunrise': 1584163713, 'sunset': 1584207343},
#   'timezone': 3600,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 5, 'speed': 0.43}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': 28.5, 'lon': -13.86},
#   'dt': 1584170864,
#   'id': 2512186,
#   'main': {'feels_like': 53.62,
#            'humidity': 72,
#            'pressure': 1019,
#            'temp': 62.82,
#            'temp_max': 64.4,
#            'temp_min': 60.8},
#   'name': 'Puerto del Rosario',
#   'sys': {'country': 'ES',
#           'id': 2371,
#           'sunrise': 1584169553,
#           'sunset': 1584212598,
#           'type': 1},
#   'timezone': 0,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 30, 'speed': 18.34}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': -9.43, 'lon': 159.95},
#   'dt': 1584170864,
#   'id': 2108502,
#   'main': {'feels_like': 95.43,
#            'humidity': 83,
#            'pressure': 1004,
#            'temp': 84.2,
#            'temp_max': 84.2,
#            'temp_min': 84.2},
#   'name': 'Honiara',
#   'sys': {'country': 'SB',
#           'id': 2,
#           'sunrise': 1584127467,
#           'sunset': 1584171273,
#           'type': 1},
#   'timezone': 39600,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 20, 'speed': 2.24}},
#  {'base': 'stations',
#   'clouds': {'all': 90},
#   'cod': 200,
#   'coord': {'lat': 41, 'lon': -115.5},
#   'dt': 1584170865,
#   'id': 5703673,
#   'main': {'feels_like': 34.95,
#            'humidity': 41,
#            'pressure': 1004,
#            'temp': 43.7,
#            'temp_max': 46,
#            'temp_min': 42.01},
#   'name': 'Elko',
#   'sys': {'country': 'US',
#           'id': 3961,
#           'sunrise': 1584194064,
#           'sunset': 1584236865,
#           'type': 1},
#   'timezone': -25200,
#   'visibility': 16093,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 240, 'speed': 6.93}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 48.93, 'lon': -125.55},
#   'dt': 1584170865,
#   'id': 6171633,
#   'main': {'feels_like': 20.26,
#            'grnd_level': 993,
#            'humidity': 49,
#            'pressure': 1008,
#            'sea_level': 1008,
#            'temp': 30.52,
#            'temp_max': 30.52,
#            'temp_min': 30.52},
#   'name': 'Ucluelet',
#   'sys': {'country': 'CA', 'sunrise': 1584196582, 'sunset': 1584239170},
#   'timezone': -25200,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 38, 'speed': 8.39}},
#  {'cod': '404', 'message': 'city not found'},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': -28.19, 'lon': 23.54},
#   'dt': 1584170865,
#   'id': 1011918,
#   'main': {'feels_like': 60.46,
#            'grnd_level': 845,
#            'humidity': 61,
#            'pressure': 1015,
#            'sea_level': 1015,
#            'temp': 66.72,
#            'temp_max': 66.72,
#            'temp_min': 66.72},
#   'name': 'Danielskuil',
#   'sys': {'country': 'ZA', 'sunrise': 1584159970, 'sunset': 1584204234},
#   'timezone': 7200,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 335, 'speed': 12.71}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': 50.12, 'lon': 139.15},
#   'dt': 1584170865,
#   'id': 2013216,
#   'main': {'feels_like': 8.56,
#            'grnd_level': 925,
#            'humidity': 84,
#            'pressure': 1005,
#            'sea_level': 1005,
#            'temp': 15.71,
#            'temp_max': 15.71,
#            'temp_min': 15.71},
#   'name': 'Vysokogornyy',
#   'snow': {'3h': 0.44},
#   'sys': {'country': 'RU', 'sunrise': 1584133169, 'sunset': 1584175553},
#   'timezone': 36000,
#   'weather': [{'description': 'light snow',
#                'icon': '13d',
#                'id': 600,
#                'main': 'Snow'}],
#   'wind': {'deg': 289, 'speed': 2.64}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 7.53, 'lon': -12.51},
#   'dt': 1584170865,
#   'id': 2409914,
#   'main': {'feels_like': 84.96,
#            'grnd_level': 1009,
#            'humidity': 90,
#            'pressure': 1009,
#            'sea_level': 1009,
#            'temp': 77.76,
#            'temp_max': 77.76,
#            'temp_min': 77.76},
#   'name': 'Bonthe',
#   'sys': {'country': 'SL', 'sunrise': 1584169025, 'sunset': 1584212479},
#   'timezone': 0,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 323, 'speed': 5.17}},
#  {'base': 'stations',
#   'clouds': {'all': 45},
#   'cod': 200,
#   'coord': {'lat': 45.23, 'lon': 147.88},
#   'dt': 1584170866,
#   'id': 2123979,
#   'main': {'feels_like': 17.71,
#            'grnd_level': 995,
#            'humidity': 68,
#            'pressure': 1013,
#            'sea_level': 1013,
#            'temp': 27.99,
#            'temp_max': 27.99,
#            'temp_min': 27.99},
#   'name': "Kuril'sk",
#   'sys': {'country': 'RU', 'sunrise': 1584130991, 'sunset': 1584173541},
#   'timezone': 36000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 209, 'speed': 9.17}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -0.22, 'lon': 20.87},
#   'dt': 1584170866,
#   'id': 218680,
#   'main': {'feels_like': 77.29,
#            'grnd_level': 969,
#            'humidity': 84,
#            'pressure': 1012,
#            'sea_level': 1012,
#            'temp': 72.75,
#            'temp_max': 72.75,
#            'temp_min': 72.75},
#   'name': 'Boende',
#   'sys': {'country': 'CD', 'sunrise': 1584160941, 'sunset': 1584204544},
#   'timezone': 3600,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04d',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 123, 'speed': 3.44}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': -15.86, 'lon': -38.88},
#   'dt': 1584170866,
#   'id': 3470137,
#   'main': {'feels_like': 79.59,
#            'humidity': 88,
#            'pressure': 1014,
#            'temp': 73.4,
#            'temp_max': 73.4,
#            'temp_min': 73.4},
#   'name': 'Belmonte',
#   'sys': {'country': 'BR',
#           'id': 8422,
#           'sunrise': 1584175115,
#           'sunset': 1584219044,
#           'type': 1},
#   'timezone': -10800,
#   'visibility': 10000,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03n',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 230, 'speed': 2.24}},
#  {'base': 'stations',
#   'clouds': {'all': 100},
#   'cod': 200,
#   'coord': {'lat': -16.22, 'lon': -69.45},
#   'dt': 1584170866,
#   'id': 3937516,
#   'main': {'feels_like': 39.33,
#            'grnd_level': 646,
#            'humidity': 76,
#            'pressure': 1022,
#            'sea_level': 1022,
#            'temp': 45.9,
#            'temp_max': 45.9,
#            'temp_min': 45.9},
#   'name': 'Juli',
#   'sys': {'country': 'PE', 'sunrise': 1584182448, 'sunset': 1584226381},
#   'timezone': -18000,
#   'weather': [{'description': 'overcast clouds',
#                'icon': '04n',
#                'id': 804,
#                'main': 'Clouds'}],
#   'wind': {'deg': 48, 'speed': 7.31}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': 69.97, 'lon': 23.27},
#   'dt': 1584170866,
#   'id': 847633,
#   'main': {'feels_like': 1.72,
#            'humidity': 85,
#            'pressure': 1004,
#            'temp': 17.56,
#            'temp_max': 19.99,
#            'temp_min': 14},
#   'name': 'Alta',
#   'sys': {'country': 'NO',
#           'id': 1606,
#           'sunrise': 1584161549,
#           'sunset': 1584202784,
#           'type': 1},
#   'timezone': 3600,
#   'visibility': 10000,
#   'weather': [{'description': 'light shower snow',
#                'icon': '13d',
#                'id': 620,
#                'main': 'Snow'}],
#   'wind': {'deg': 340, 'gust': 31.09, 'speed': 18.34}},
#  {'base': 'stations',
#   'clouds': {'all': 20},
#   'cod': 200,
#   'coord': {'lat': 26.88, 'lon': 93.63},
#   'dt': 1584170866,
#   'id': 1271074,
#   'main': {'feels_like': 87.12,
#            'humidity': 48,
#            'pressure': 1012,
#            'temp': 84.2,
#            'temp_max': 84.2,
#            'temp_min': 84.2},
#   'name': 'Gohpur',
#   'sys': {'country': 'IN',
#           'id': 9123,
#           'sunrise': 1584143758,
#           'sunset': 1584186809,
#           'type': 1},
#   'timezone': 19800,
#   'visibility': 4000,
#   'weather': [{'description': 'haze',
#                'icon': '50d',
#                'id': 721,
#                'main': 'Haze'}],
#   'wind': {'deg': 190, 'speed': 2.24}},
#  {'base': 'stations',
#   'clouds': {'all': 0},
#   'cod': 200,
#   'coord': {'lat': 18.69, 'lon': 12.92},
#   'dt': 1584170867,
#   'id': 2446796,
#   'main': {'feels_like': 52.2,
#            'grnd_level': 965,
#            'humidity': 24,
#            'pressure': 1017,
#            'sea_level': 1017,
#            'temp': 60.53,
#            'temp_max': 60.53,
#            'temp_min': 60.53},
#   'name': 'Bilma',
#   'sys': {'country': 'NE', 'sunrise': 1584163031, 'sunset': 1584206268},
#   'timezone': 3600,
#   'weather': [{'description': 'clear sky',
#                'icon': '01d',
#                'id': 800,
#                'main': 'Clear'}],
#   'wind': {'deg': 62, 'speed': 6.55}},
#  {'base': 'stations',
#   'clouds': {'all': 82},
#   'cod': 200,
#   'coord': {'lat': 66.77, 'lon': 123.37},
#   'dt': 1584170867,
#   'id': 2012530,
#   'main': {'feels_like': -15.3,
#            'grnd_level': 1007,
#            'humidity': 92,
#            'pressure': 1013,
#            'sea_level': 1013,
#            'temp': -5.37,
#            'temp_max': -5.37,
#            'temp_min': -5.37},
#   'name': 'Zhigansk',
#   'sys': {'country': 'RU', 'sunrise': 1584137432, 'sunset': 1584178862},
#   'timezone': 32400,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 184, 'speed': 5.99}},
#  {'base': 'stations',
#   'clouds': {'all': 26},
#   'cod': 200,
#   'coord': {'lat': 22.81, 'lon': 89.57},
#   'dt': 1584170867,
#   'id': 1336135,
#   'main': {'feels_like': 90,
#            'grnd_level': 1012,
#            'humidity': 25,
#            'pressure': 1013,
#            'sea_level': 1013,
#            'temp': 94.77,
#            'temp_max': 94.77,
#            'temp_min': 94.77},
#   'name': 'Khulna',
#   'sys': {'country': 'BD', 'sunrise': 1584144688, 'sunset': 1584187827},
#   'timezone': 21600,
#   'weather': [{'description': 'scattered clouds',
#                'icon': '03d',
#                'id': 802,
#                'main': 'Clouds'}],
#   'wind': {'deg': 13, 'speed': 10.33}},
#  {'base': 'stations',
#   'clouds': {'all': 75},
#   'cod': 200,
#   'coord': {'lat': -21.37, 'lon': 55.62},
#   'dt': 1584170867,
#   'id': 6690296,
#   'main': {'feels_like': 75.33,
#            'humidity': 74,
#            'pressure': 1012,
#            'temp': 79.7,
#            'temp_max': 82.4,
#            'temp_min': 73},
#   'name': 'Saint-Joseph',
#   'sys': {'country': 'RE',
#           'id': 2127,
#           'sunrise': 1584152363,
#           'sunset': 1584196445,
#           'type': 1},
#   'timezone': 14400,
#   'visibility': 10000,
#   'weather': [{'description': 'broken clouds',
#                'icon': '04d',
#                'id': 803,
#                'main': 'Clouds'}],
#   'wind': {'deg': 130, 'speed': 21.92}},
#  {'base': 'stations',
#   'clouds': {'all': 16},
#   'cod': 200,
#   'coord': {'lat': -34.62, 'lon': -68.33},
#   'dt': 1584170867,
#   'id': 3836669,
#   'main': {'feels_like': 63.72,
#            'grnd_level': 915,
#            'humidity': 49,
#            'pressure': 1016,
#            'sea_level': 1016,
#            'temp': 67.91,
#            'temp_max': 67.91,
#            'temp_min': 67.91},
#   'name': 'San Rafael',
#   'rain': {'3h': 0.63},
#   'sys': {'country': 'AR', 'sunrise': 1584181926, 'sunset': 1584226365},
#   'timezone': -10800,
#   'weather': [{'description': 'light rain',
#                'icon': '10n',
#                'id': 500,
#                'main': 'Rain'}],
#   'wind': {'deg': 172, 'speed': 6.69}},
#  {'base': 'stations',
#   'clouds': {'all': 40},
#   'cod': 200,
#   'coord': {'lat': -0.72, 'lon': 8.78},
#   'dt': 1584170867,
#   'id': 2396518,
#   'main': {'feels_like': 93,
#            'humidity': 88,
#            'pressure': 1010,
#            'temp': 82.4,
#            'temp_max': 82.4,
#            'temp_min': 82.4},
#   'name': 'Port-Gentil',
#   'sys': {'country': 'GA',
#           'id': 2188,
#           'sunrise': 1584163837,
#           'sunset': 1584207450,
#           'type': 1},
#   'timezone': 3600,
#   'visibility': 8000,
#   'weather': [{'description': 'thunderstorm with light rain',
#                'icon': '11d',
#                'id': 200,
#                'main': 'Thunderstorm'}],
#   'wind': {'speed': 3.36}}]
